# %%
import pandas as pd

# %%
data = pd.read_excel('FINAL Separated Narratives.xlsx').set_index('ID')

# %%
data
# Out:
#            Unnamed: 0  Priority                    CallType  \
# ID
# 2020_2              0         1           Breathing Problem
# 2020_3              1         1           Breathing Problem
# 2020_4              2         2                       Falls
# 2020_5              3         1           Breathing Problem
# 2020_6              4         1  Chest Pain (Non-Traumatic)
# ...               ...       ...                         ...
# 2017_7299       35921         2             Unknown Problem
# 2017_7300       35922         2             Unknown Problem
# 2017_7301       35923         2             Unknown Problem
# 2017_7302       35924         3             Unknown Problem
# 2017_7303       35925         3             Unknown Problem
#
#                                               ChiefComplaint  \
# ID
# 2020_2             ""PAIN TO THE LEFT SIDE OF MY BODY"""SOB"
# 2020_3     "Shortness of breath, nausea, vomiting, dizzin...
# ...

# %%
cts = set()

for index, row in data.iterrows():
    ct = row['CallType']
    cts.add(ct)

cts
# Out:
# {'<None>',
#  'ALS Transfer',
#  'Abdominal Pain',
#  'Abdominal Pain/Problems',
#  'Allergic Reaction',
#  'Allergic Reaction/Stings',
#  'Animal Attack/Bite',
#  'Animal Bite',
#  'Assault',
#  'Assault/Rape',
#  'Back Pain',
#  'Back Pain (Non-Traumatic)',
#  'Breathing Problem',
#  'Breathing Problems',
#  'Burn(s)',
#  'Burns/Explosion',
#  'Carbon Monoxide/Hazmat/Inhalation/CBRN',
#  'Cardiac Arrest/Death',
#  'Cardiac/Resp Arrest',
#  'Chest Pain',
#  'Chest Pain (Non-Traumatic)',
#  'Choking',
#  'Convulsions/Seizure',
#  'Critical Care Transport',
#  'Diabetic Problem',
#  'Diabetic Problems',
#  'Drowning',
#  'Drowning/Diving/SCUBA Accident',
#  'Electrical Shock',
#  'Electrocution/Lightning',
#  'Eye Problem/Injury',
#  'Eye Problems/Injuries',
#  'Fall(s)',
#  'Falls',
#  'Fire',
#  'Headache',
#  'Heart Problems',
#  'Heart Problems/AICD',
#  'Heat/Cold Exposure',
#  'Hemorhage/Lacerations',
#  'Hemorrhage/Laceration',
#  'Industrial Accident',
# ...

# %%
pd.DataFrame(list(cts)).to_excel('Dictionary for Call Types.xlsx')
