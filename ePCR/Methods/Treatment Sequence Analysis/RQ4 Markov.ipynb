# %%
'''
    My implementation  (pseudocode)
    For each impression, read through all time-series arrays including the impression:
        For each array of time-series:
        Start with adding 'start node' to graph
        For each time-series in the array:
            if the intervention is not already in outside dictionary: 
                add the id of the intervention as key to outside dictionary, and initialize value as empty dict
            if there is no next intervention, the id/next node is 'end'
            if id of the next intervention is NOT in inside dictionary for current node:
                add the id of next intervention as key to the value dictionary, and initialize value as 1
            if id of next intervention IS in the dictionary for current node:
                value of next intervention ++
'''
import pandas as pd

# %%
#groupings of procedures to further clean graph

temp_pros = pd.read_excel('GROUPED list of Procedures.xlsx').set_index(['Grouping'])
temp_pros['Snomed'] = temp_pros['Snomed'].astype(str)
grouped_pros = {}
for group, row in temp_pros.iterrows():
    sno = row['Snomed']
    grouped_pros[sno] = group 
    
grouped_pros
# Out:
# {'404996007': 'Access Airway',
#  '232707004': 'Clear Airway',
#  '23690002': 'Clear Airway',
#  '232708009': 'Clear Airway',
#  '230040009': 'Clear Airway',
#  '232664002': 'Open/Position Airway',
#  '51717002': 'ETCO2 Capnography',
#  '425543005': 'ETCO2 Capnography',
#  '19821003': 'ETCO2 Capnography',
#  '284029005': 'ETCO2 Capnography',
#  '104690002': 'Glucose Check',
#  '302789003': 'Glucose Check',
#  '406164000': 'Restraint Applied',
#  '386423001': 'Restraint Applied',
#  '241741007': 'Patient Cooling/Warming',
#  '241740008': 'Patient Cooling/Warming',
#  '421335007': 'Patient Cooling/Warming',
#  '229585002': 'Patient Cooling/Warming',
#  '398074008': 'Patient Cooling/Warming',
#  '431774007': 'Patient Cooling/Warming',
#  '431949004': 'Patient Cooling/Warming',
#  '429283006': 'CPR',
#  '441893003': 'CPR',
#  '89666000': 'CPR',
#  '425519007': 'CPR Discontinued',
#  '18590009': 'Cardiac Pacing',
#  '250980009': 'Cardioversion',
#  '426220008': 'Defibrillation',
#  '233169004': 'Defibrillation',
#  '268400002': 'ECG',
#  '428803005': 'ECG',
#  '46825001': 'ECG',
#  '49999004': 'Irrigation',
#  '67889009': 'Irrigation',
#  '87750000': 'Gastric Tube Insertion',
#  '52260009': 'Gastric Tube Insertion',
#  '235425002': 'Gastric Tube Insertion',
#  '384745002': 'Gastric Tube Insertion',
#  '40174006': 'Isolation Procedure',
#  '430824005': 'IV/IO',
#  '396540005': 'IV/IO',
#  '424287005': 'IV/IO',
#  '353008': 'IV/IO',
#  '405677002': 'IV/IO',
#  '405427009': 'IV/IO',
#  '392230005': 'IV/IO',
#  '225157004': 'IV/IO',
#  '398213004': 'Move Patient',
#  '56469005': 'Move Patient',
#  '58715004': 'Move Patient',
#  '49689007': 'Stabilization/Splinting',
#  '398041008': 'Stabilization/Splinting',
#  '449199004': 'Stabilization/Splinting',
#  '426498007': 'Stabilization/Splinting',
#  '79321009': 'Stabilization/Splinting',
#  '302488007': 'Stabilization/Splinting',
#  '79821001': 'Stabilization/Splinting',
#  '236973005': 'Assist Childbirth',
#  '425447009': 'BVM',
#  '243140006': 'BVM',
#  '243142003': 'CPAP/BiPAP',
#  '47545007': 'CPAP/BiPAP',
#  '385857005': 'CPAP/BiPAP',
#  '243161004': 'CPAP/BiPAP',
#  '398292008': 'CPAP/BiPAP',
#  '409025002': 'CPAP/BiPAP',
#  '56251003': 'Nebulizer Therapy',
#  '19861002': 'Nebulizer Therapy',
#  '426970003': 'ROSC',
#  '447686008': 'Bleeding Control',
#  '372045002': 'Bleeding Control',
#  '26906007': 'Bleeding Control',
#  '51241000': 'Bleeding Control',
#  '20655006': 'Bleeding Control',
#  '133901003': 'Burn Care',
#  '225150002': 'Wound Care',
#  '22206003': 'Wound Care',
#  '182531007': 'Wound Care',
#  '225358003': 'Wound Care',
#  '225116006': 'Wound Care',
#  '225399009': 'Vitals/Assess',
#  '252465000': 'Vitals/Assess',
#  '61746007': 'Vitals/Assess',
#  '182777000': 'Monitor/Care',
#  '226005007': 'Monitor/Care',
#  '422618004': 'Monitor/Care',
#  '83887000': 'Extrication',
#  '59108006': 'IM/SQ Injection',
#  '232692007': 'Cricothyrotomy',
#  '2267008': 'Cricothyrotomy',
#  '182705007': 'Thoracostomy',
#  '367408005': 'Thoracostomy',
#  '450611000124100': 'Intubation',
#  '78121007': 'Intubation',
#  '182692007': 'Intubation',
#  '7443007': 'Intubation',
#  '52765003': 'Intubation',
#  '241726007': 'Intubation',
#  '232685002': 'Intubation',
#  '405639008': 'Intubation',
#  '271280005': 'Intubation',
#  '398024006': 'Intubation',
#  '398279005': 'Intubation',
#  '232674004': 'Intubation',
#  '241689008': 'Intubation',
#  '409088002': 'Intubation',
#  '16883004': 'Intubation',
#  '128968000': 'Vagal Maneuver',
#  '304562007': 'Filter Out',
#  '410669006': 'Filter Out'}

# %%
#medications

temp_meds = pd.read_excel('Complied list of ODEMSA Medications.xlsx').set_index(['Medications'])
temp_meds['RxCui'] = temp_meds['RxCui'].astype(str)
med_dict = {}
for group, row in temp_meds.iterrows():
    rxcui = row['RxCui']
    med_dict[rxcui] = group 
    
med_dict
# Out:
# {'828527': '10 ML calcium chloride 10 % Prefilled Syringe',
#  '161': 'Acetaminophen (Tylenol)',
#  '296': 'Adenosine (Adenocard)',
#  '435': 'Albuterol (Proventil)',
#  '214199': 'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)',
#  '8410': 'Alteplase (Activase)',
#  '703': 'Amiodarone (Cordarone)',
#  'T195': 'Antibiotics',
#  '1191': 'Aspirin (ASA)',
#  '1223': 'Atropine',
#  '153971': 'Atropine Sulfate',
#  '205489': 'Bumetanide (Bumex)',
#  '1901': 'Calcium Chloride',
#  '197435': 'Calcium Gluconate 100 MG/ML Injectable Solution',
#  '687707': 'CYANOKIT 5g',
#  '575233': 'Dexamethasone (Decadron)',
#  '1812079': 'Dexamethasone 10mg IV/IM',
#  '48933': 'Dexamethasone 10MG PO',
#  '4850': 'Dextrose',
#  '237648': 'Dextrose 10 % Injectable Solution',
#  '727518': 'Dextrose 25%',
#  '1795250': 'Dextrose 5% in 0.45% NS',
#  '237653': 'Dextrose 50 % Injectable Solution',
#  '3322': 'Diazepam (Valium)',
#  '3443': 'Diltiazem (Cardizem)',
#  '3498': 'Diphenhydramine (Benadryl)',
#  '3616': 'Dobutamine',
#  '3628': 'Dopamine',
#  '67108': 'Enoxaparin',
#  '328316': 'Epinephrine 1:1,000',
#  '317361': 'Epinephrine 1:10,000',
#  '727347': 'Epipen Adult',
#  '4177': 'Etomidate (Amidate)',
#  '4337': 'Fentanyl',
#  '4603': 'Furosemide (Lasix)',
#  '1719286': 'Furosemide 10 MG/ML',
#  '8375': 'Generic Medication Placeholder',
#  '4832': 'Glucagon (Glucagen)',
#  '92821': 'Glutose',
#  '151839': 'Haldol',
#  '5224': 'Heparin',
#  '5470': 'Hydralazine (Apresoline)',
#  '5514': 'Hydroxocobalamin (Cyanokit)',
#  '5856': 'Insulin',
#  '7213': 'Ipratropium (Atrovent)',
#  '6130': 'Ketamine (Ketalar)',
#  '35827': 'Ketorolac (Toradol)',
#  '6185': 'Labetalol (Normodyne)',
#  '35629': "Lactated Ringer's Solution",
#  '237159': 'Levalbuterol (Xopenex)',
#  '6387': 'Lidocaine',
#  '6470': 'Lorazepam (Ativan)',
#  '6585': 'Magnesium Sulfate',
#  '6902': 'Methylprednisolone (Solu-MEDROL)',
#  '6918': 'Metoprolol (Lopresser)',
#  '6960': 'Midazolam (Versed)',
#  '7052': 'Morphine',
#  '30236': 'Morphine Sulfate',
#  '7242': 'Naloxone (Narcan)',
#  '204346': 'Neo-Synephrine',
#  '7396': 'Nicardipine (Cardene)',
#  '4917': 'Nitroglycerin',
#  '7476': 'Nitroprusside (Nitropress)',
#  '7512': 'Norepinephrine (Levophed)',
#  '125464': 'Normal saline',
#  '26225': 'Ondansetron (Zofran)',
#  '7806': 'Oxygen',
#  '7812': 'Oxymetazoline (Afrin)',
#  '8163': 'Phenylephrine (Neo-Synephrine)',
#  '8183': 'Phenytoin (Dilantin)',
#  '8591': 'Potassium Chloride',
#  '262138': 'Precedex',
#  '8640': 'Prednisone',
#  '8745': 'Promethazine (Phenergan)',
#  '8782': 'Propofol (Diprivan)',
#  '1808218': 'Propofol Injection (Diprivan)',
#  '314610': 'Racemic Epinephrine',
#  '68139': 'Rocuronium (Zemuron)',
#  '36676': 'Sodium Bicarbonate',
#  '10154': 'Succinylcholine (Anectine)',
#  '857634': 'Terbutaline Sulfate 1 MG/ML',
#  '11149': 'Vasopressin (USP)',
#  '11153': 'Vecuronium Bromide (Norcuron)',
#  '285064': 'Ziprasidone (Geodon)'}

# %%
dataframes = {}

xl = pd.ExcelFile('RQ4 WITH MOST COMMON - Graph Set 2 Data.xlsx')
impressions = xl.sheet_names

for sheet in impressions:
    dataframes[f'{sheet}']= pd.read_excel(xl,sheet_name=sheet)
    
dataframes
# Out:
# {'Seizures':       Unnamed: 0                                           Sequence
#  0              0  start,230040009,425543005,428803005,6960,6960,...
#  1              1            start,398041008,392230005,428803005,end
#  2              2                      start,392230005,428803005,end
#  3              3  start,6960,425543005,392230005,125464,42880300...
#  4              4               start,392230005,428803005,125464,end
#  ...          ...                                                ...
#  1748        1748  start,46825001,392230005,392230005,392230005,2...
#  1749        1749  start,7806,46825001,268400002,392230005,6960,2...
#  1750        1750  start,46825001,392230005,392230005,6960,7806,3...
#  1751        1751                  start,46825001,392230005,6960,end
#  1752        1752      start,386423001,285064,46825001,6960,7806,end
#
#  [1753 rows x 2 columns],
#  'Chest Pain (Angina Cardiac)':       Unnamed: 0                                           Sequence
#  0              0                 start,428803005,268400002,1191,end
#  1              1  start,428803005,268400002,1191,268400002,39223...
#  2              2  start,428803005,1191,268400002,268400002,39223...
#  3              3  start,428803005,392230005,268400002,268400002,end
#  4              4                 start,428803005,268400002,1191,end
#  ...          ...                                                ...
#  4582        4582   start,46825001,268400002,392230005,4850,4850,end
#  4583        4583        start,268400002,392230005,1191,46825001,end
#  4584        4584  start,1191,46825001,268400002,392230005,268400...
#  4585        4585   start,46825001,268400002,1191,392230005,4917,end
#  4586        4586   start,46825001,268400002,1191,7806,268400002,end
#
#  [4587 rows x 2 columns],
#  'Chest Pain (STEMI MI)':      Unnamed: 0                                           Sequence
#  0             0  start,425543005,392230005,428803005,268400002,...
#  1             1  start,428803005,268400002,392230005,4917,4917,end
#  2             2       start,428803005,392230005,268400002,1191,end
#  3             3                      start,428803005,268400002,end
#  4             4  start,428803005,392230005,268400002,268400002,...
#  ..          ...                                                ...
#  492         492        start,4917,46825001,268400002,268400002,end
#  493         493   start,46825001,5224,7806,268400002,392230005,end
#  494         494                  start,5224,268400002,46825001,end
#  495         495  start,1191,67108,7806,392230005,46825001,26840...
#  496         496  start,46825001,268400002,1191,392230005,4917,7...
#
#  [497 rows x 2 columns],
#  'Cardiac Arrest':      Unnamed: 0                                           Sequence
#  0             0  start,428803005,429283006,232674004,430824005,...
#  1             1  start,429283006,425447009,7242,430824005,31736...
#  2             2  start,7806,425447009,89666000,428803005,429283...
#  3             3  start,51717002,7443007,425543005,429283006,232...
#  4             4  start,425447009,89666000,429283006,392230005,3...
#  ..          ...                                                ...
#  909         909  start,450611000124100,89666000,7806,425447009,...
#  910         910  start,89666000,425447009,46825001,52765003,230...
#  911         911  start,89666000,392230005,7806,46825001,317361,...
#  912         912  start,46825001,7806,89666000,392230005,36676,3...
#  913         913  start,46825001,425447009,89666000,89666000,527...
#
#  [914 rows x 2 columns],
#  'Hypoglycemia':       Unnamed: 0                                           Sequence
#  0              0                 start,392230005,4832,428803005,end
#  1              1  start,49689007,428803005,4850,268400002,392230...
#  2              2  start,7806,7806,392230005,392230005,237648,428...
#  3              3  start,237648,425543005,428803005,392230005,392...
#  4              4  start,392230005,4832,392230005,392230005,23764...
#  ...          ...                                                ...
#  1112        1112                start,46825001,392230005,237648,end
#  1113        1113  start,392230005,237648,46825001,237648,2684000...
#  1114        1114          start,46825001,237648,392230005,26225,end
#  1115        1115                start,46825001,392230005,237648,end
#  1116        1116  start,46825001,392230005,237648,268400002,2684...
#
#  [1117 rows x 2 columns],
#  'Stroke':      Unnamed: 0                                           Sequence
#  0             0  start,428803005,392230005,268400002,392230005,end
#  1             1  start,428803005,7806,182692007,392230005,26840...
#  2             2                      start,428803005,392230005,end
#  3             3                 start,7806,428803005,268400002,end
#  4             4  start,428803005,268400002,392230005,268400002,end
#  ..          ...                                                ...
#  893         893                            start,46825001,8410,end
#  894         894  start,46825001,392230005,392230005,392230005,2...
#  895         895  start,392230005,392230005,268400002,268400002,...
#  896         896  start,4850,46825001,268400002,392230005,237648...
#  897         897  start,46825001,392230005,392230005,6960,7806,3...
#
#  [898 rows x 2 columns]}

# %%
#initialize graphs
graphs = {}

for sheet_name, data in dataframes.items():
    graph = {}
    #for each array of time series, start with adding 'start node' to graph
    for index, array_string in data['Sequence'].iteritems():
        array = array_string.split(",")
        for i in range(len(array)):
            node = array[i]
            if node in grouped_pros: 
                node = grouped_pros[node]
            elif node in med_dict:
                node = med_dict[node]
                
            if node not in graph: graph[node] = {}
            next_node_index = i + 1
            #if there is no next intervention
            if next_node_index == len(array): break #stop, you went through all nodes
            next_node = array[next_node_index]
            if next_node in grouped_pros: 
                next_node = grouped_pros[next_node]
            elif next_node in med_dict:
                next_node = med_dict[next_node]
                
            if next_node not in graph[node]:
                graph[node][next_node] = 1
            else:
                graph[node][next_node] += 1
    #after you go through the entire sheet
    graphs[sheet_name] = graph

# %%
graphs
# Out:
# {'Seizures': {'start': {'Clear Airway': 11,
#    'Stabilization/Splinting': 48,
#    'IV/IO': 362,
#    'Midazolam (Versed)': 140,
#    'ECG': 893,
#    'Normal saline': 20,
#    'Ondansetron (Zofran)': 2,
#    'Oxygen': 156,
#    'Restraint Applied': 16,
#    'ETCO2 Capnography': 35,
#    'Intubation': 11,
#    'Dextrose': 6,
#    'Wound Care': 2,
#    'BVM': 6,
#    'Monitor/Care': 5,
#    'Aspirin (ASA)': 2,
#    'Naloxone (Narcan)': 7,
#    'Glucose Check': 5,
#    'Dextrose 10 % Injectable Solution': 4,
#    'Bleeding Control': 6,
#    'Open/Position Airway': 2,
#    'CPR': 3,
#    'CPAP/BiPAP': 1,
#    'Glucagon (Glucagen)': 2,
#    'Lorazepam (Ativan)': 1,
#    'Generic Medication Placeholder': 1,
#    'Haldol': 1,
#    'Albuterol (Proventil)': 1,
#    'Fentanyl': 2,
#    'Cardiac Pacing': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1},
#   'Clear Airway': {'ETCO2 Capnography': 5,
#    'ECG': 19,
#    'end': 7,
#    'Intubation': 4,
#    'Glucose Check': 1,
#    'BVM': 3,
#    'Clear Airway': 1,
#    'Oxygen': 4,
#    'IV/IO': 8,
#    'Midazolam (Versed)': 11,
#    'Stabilization/Splinting': 1,
#    'Glucagon (Glucagen)': 1,
#    'Monitor/Care': 1,
#    'Epinephrine 1:10,000': 1,
#    'Defibrillation': 1},
#   'ETCO2 Capnography': {'ECG': 61,
#    'IV/IO': 38,
#    'end': 20,
#    'Oxygen': 8,
#    'Glucose Check': 4,
#    'Clear Airway': 3,
#    'Normal saline': 2,
#    'Midazolam (Versed)': 11,
#    'Intubation': 2,
#    'CPAP/BiPAP': 2,
#    'Ipratropium (Atrovent)': 1,
#    'Access Airway': 1,
#    'BVM': 1,
#    'Defibrillation': 2,
#    'ETCO2 Capnography': 7,
#    'Ondansetron (Zofran)': 1},
#   'ECG': {'Midazolam (Versed)': 162,
#    'end': 757,
#    'Normal saline': 49,
#    'IV/IO': 857,
#    'ETCO2 Capnography': 38,
#    'Intubation': 16,
#    'ECG': 834,
#    'Albuterol (Proventil)': 3,
#    'BVM': 6,
#    'Oxygen': 104,
#    'Glucose Check': 4,
#    'Ondansetron (Zofran)': 8,
#    'Clear Airway': 13,
#    'Wound Care': 2,
#    'Aspirin (ASA)': 9,
#    'Restraint Applied': 11,
#    'Dextrose': 2,
#    'Patient Cooling/Warming': 2,
#    'Stabilization/Splinting': 5,
#    'Fentanyl': 1,
#    'Dextrose 10 % Injectable Solution': 5,
#    'Naloxone (Narcan)': 4,
#    'Adenosine (Adenocard)': 1,
#    'Monitor/Care': 3,
#    'Phenytoin (Dilantin)': 1,
#    'Magnesium Sulfate': 1,
#    'Glutose': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1,
#    'Nitroglycerin': 1,
#    'CPR': 1},
#   'Midazolam (Versed)': {'Midazolam (Versed)': 57,
#    'Oxygen': 99,
#    'ETCO2 Capnography': 23,
#    'Intubation': 13,
#    'ECG': 157,
#    'Haldol': 1,
#    'end': 205,
#    'Clear Airway': 6,
#    'Normal saline': 17,
#    'Naloxone (Narcan)': 5,
#    'IV/IO': 83,
#    'Restraint Applied': 9,
#    'Ondansetron (Zofran)': 3,
#    'BVM': 7,
#    'Monitor/Care': 1,
#    'Stabilization/Splinting': 2,
#    'Patient Cooling/Warming': 1,
#    'Glucagon (Glucagen)': 1,
#    'Cardioversion': 1},
#   'Oxygen': {'end': 75,
#    'Midazolam (Versed)': 51,
#    'IV/IO': 104,
#    'Nebulizer Therapy': 2,
#    'ETCO2 Capnography': 28,
#    'ECG': 137,
#    'Clear Airway': 18,
#    'BVM': 25,
#    'Intubation': 12,
#    'Normal saline': 4,
#    'Oxygen': 6,
#    'Patient Cooling/Warming': 1,
#    'Restraint Applied': 6,
#    'Naloxone (Narcan)': 2,
#    'Stabilization/Splinting': 5,
#    'Glucose Check': 1,
#    'Monitor/Care': 1,
#    'Open/Position Airway': 1,
#    'Ondansetron (Zofran)': 1,
#    'Epinephrine 1:10,000': 1},
#   'end': {},
#   'Stabilization/Splinting': {'IV/IO': 17,
#    'Stabilization/Splinting': 9,
#    'ECG': 40,
#    'end': 4,
#    'Clear Airway': 2,
#    'ETCO2 Capnography': 1,
#    'Midazolam (Versed)': 3,
#    'Bleeding Control': 2,
#    'Oxygen': 1,
#    'Restraint Applied': 1,
#    'Extrication': 1,
#    'Wound Care': 1},
#   'IV/IO': {'ECG': 618,
#    'Normal saline': 63,
#    'end': 504,
#    'Midazolam (Versed)': 202,
#    'Oxygen': 54,
#    'IV/IO': 125,
#    'Naloxone (Narcan)': 14,
#    'Albuterol (Proventil)': 1,
#    'ETCO2 Capnography': 11,
#    'Intubation': 6,
#    'Clear Airway': 6,
#    'Ondansetron (Zofran)': 23,
#    'Dextrose 10 % Injectable Solution': 17,
#    'Restraint Applied': 11,
#    'Stabilization/Splinting': 9,
#    'Epinephrine 1:10,000': 6,
#    'BVM': 4,
#    'Ketorolac (Toradol)': 1,
#    'Monitor/Care': 2,
#    'Glucagon (Glucagen)': 6,
#    'Bleeding Control': 2,
#    'Vagal Maneuver': 1,
#    'Glucose Check': 1,
#    'Magnesium Sulfate': 2,
#    'Diphenhydramine (Benadryl)': 1,
#    'Dexamethasone (Decadron)': 4,
#    'CPR': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 2,
#    'Aspirin (ASA)': 2,
#    'Dextrose': 2},
#   'Normal saline': {'ECG': 26,
#    'end': 66,
#    'Restraint Applied': 3,
#    'Oxygen': 12,
#    'IV/IO': 35,
#    'Midazolam (Versed)': 10,
#    'Aspirin (ASA)': 1,
#    'Intubation': 1,
#    'Ondansetron (Zofran)': 4,
#    'Adenosine (Adenocard)': 1,
#    'Naloxone (Narcan)': 1,
#    'ETCO2 Capnography': 1},
#   'Intubation': {'Oxygen': 8,
#    'ECG': 17,
#    'BVM': 10,
#    'end': 13,
#    'IV/IO': 16,
#    'ETCO2 Capnography': 3,
#    'Midazolam (Versed)': 9,
#    'Normal saline': 1,
#    'Epinephrine 1:10,000': 4,
#    'Intubation': 2,
#    'Clear Airway': 3},
#   'Restraint Applied': {'ECG': 22,
#    'IV/IO': 7,
#    'Midazolam (Versed)': 11,
#    'end': 10,
#    'ETCO2 Capnography': 3,
#    'Oxygen': 3,
#    'Monitor/Care': 1,
#    'Intubation': 1,
#    'Ziprasidone (Geodon)': 1},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 2,
#    'Oxygen': 1,
#    'ETCO2 Capnography': 1,
#    'end': 2},
#   'Ipratropium (Atrovent)': {'Oxygen': 3},
#   'Ondansetron (Zofran)': {'ECG': 6,
#    'end': 29,
#    'Midazolam (Versed)': 2,
#    'Clear Airway': 1,
#    'IV/IO': 3,
#    'ETCO2 Capnography': 1},
#   'Naloxone (Narcan)': {'ECG': 10,
#    'Oxygen': 6,
#    'ETCO2 Capnography': 2,
#    'end': 9,
#    'IV/IO': 1,
#    'Midazolam (Versed)': 1,
#    'Normal saline': 4,
#    'Naloxone (Narcan)': 2,
#    'Haldol': 1,
#    'Intubation': 2},
#   'Haldol': {'Intubation': 1, 'Midazolam (Versed)': 1, 'end': 1},
#   'Nebulizer Therapy': {'ECG': 2},
#   'BVM': {'end': 7,
#    'IV/IO': 17,
#    'Midazolam (Versed)': 8,
#    'ECG': 12,
#    'Oxygen': 6,
#    'Intubation': 9,
#    'Naloxone (Narcan)': 1,
#    'Defibrillation': 1,
#    'Clear Airway': 2,
#    'Bleeding Control': 1},
#   'Glucose Check': {'end': 3,
#    'BVM': 1,
#    'Midazolam (Versed)': 1,
#    'IV/IO': 5,
#    'ECG': 5,
#    'Stabilization/Splinting': 1},
#   'Dextrose': {'IV/IO': 2, 'ECG': 2, 'Dextrose': 3, 'end': 7},
#   'Wound Care': {'Bleeding Control': 1,
#    'Stabilization/Splinting': 1,
#    'ECG': 2,
#    'Patient Cooling/Warming': 1},
#   'Bleeding Control': {'Patient Cooling/Warming': 1,
#    'Stabilization/Splinting': 1,
#    'ECG': 4,
#    'end': 1,
#    'IV/IO': 4,
#    'ETCO2 Capnography': 1},
#   'Patient Cooling/Warming': {'end': 3,
#    'Clear Airway': 1,
#    'Restraint Applied': 1,
#    'IV/IO': 1},
#   'Monitor/Care': {'ECG': 8,
#    'CPAP/BiPAP': 2,
#    'end': 1,
#    'Vitals/Assess': 1,
#    'ETCO2 Capnography': 1,
#    'IV/IO': 1},
#   'Aspirin (ASA)': {'end': 3,
#    'ECG': 4,
#    'IV/IO': 5,
#    'Midazolam (Versed)': 1,
#    'Oxygen': 1},
#   'Dextrose 10 % Injectable Solution': {'end': 9,
#    'ECG': 8,
#    'Midazolam (Versed)': 1,
#    'IV/IO': 4,
#    'Oxygen': 4,
#    'Naloxone (Narcan)': 1,
#    'Dextrose 10 % Injectable Solution': 1},
#   'CPAP/BiPAP': {'ECG': 3, 'end': 1, 'Potassium Chloride': 1},
#   'Epinephrine 1:10,000': {'Intubation': 3,
#    'ECG': 1,
#    'Defibrillation': 1,
#    'Amiodarone (Cordarone)': 1,
#    'end': 3,
#    'Midazolam (Versed)': 1,
#    'ETCO2 Capnography': 3,
#    'CPR': 1,
#    'Gastric Tube Insertion': 1,
#    'Naloxone (Narcan)': 1,
#    'Epinephrine 1:10,000': 1,
#    'Oxygen': 1},
#   'Open/Position Airway': {'Intubation': 1, 'IV/IO': 1, 'ECG': 1},
#   'CPR': {'ECG': 1,
#    'Defibrillation': 1,
#    'CPR': 2,
#    'Intubation': 1,
#    'IV/IO': 2,
#    'Epinephrine 1:10,000': 1,
#    'BVM': 1},
#   'Defibrillation': {'CPR': 1,
#    'Defibrillation': 2,
#    'IV/IO': 1,
#    'Epinephrine 1:10,000': 1,
#    'end': 2,
#    'Amiodarone (Cordarone)': 2},
#   'Amiodarone (Cordarone)': {'Epinephrine 1:10,000': 3},
#   'Fentanyl': {'end': 1, 'Normal saline': 1, 'ECG': 1},
#   'Glucagon (Glucagen)': {'Dextrose 10 % Injectable Solution': 1,
#    'Midazolam (Versed)': 2,
#    'end': 4,
#    'ECG': 1,
#    'Dextrose': 1,
#    'Oxygen': 1},
#   'Adenosine (Adenocard)': {'ECG': 1, 'Midazolam (Versed)': 1},
#   'Ketorolac (Toradol)': {'Midazolam (Versed)': 1},
#   'Lorazepam (Ativan)': {'ECG': 1},
#   'Phenytoin (Dilantin)': {'Restraint Applied': 1},
#   'Generic Medication Placeholder': {'Midazolam (Versed)': 1},
#   'Extrication': {'ECG': 1},
#   'Vitals/Assess': {'end': 1},
#   'Access Airway': {'end': 1},
#   'Potassium Chloride': {'end': 1},
#   'Vagal Maneuver': {'ECG': 1},
#   'Cardioversion': {'Defibrillation': 1},
#   'Magnesium Sulfate': {'end': 1, 'Midazolam (Versed)': 2},
#   'Diphenhydramine (Benadryl)': {'Midazolam (Versed)': 1},
#   'Dexamethasone (Decadron)': {'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1,
#    'ECG': 1,
#    'Albuterol (Proventil)': 1,
#    'end': 2},
#   'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': {'Oxygen': 3,
#    'IV/IO': 1,
#    'Dexamethasone (Decadron)': 1},
#   'Cardiac Pacing': {'Intubation': 1},
#   'Gastric Tube Insertion': {'Clear Airway': 1},
#   'Glutose': {'IV/IO': 1},
#   'Nitroglycerin': {'ECG': 1},
#   'Ziprasidone (Geodon)': {'ECG': 1}},
#  'Chest Pain (Angina Cardiac)': {'start': {'ECG': 3141,
#    'IV/IO': 263,
#    'Aspirin (ASA)': 784,
#    'Oxygen': 223,
#    'Monitor/Care': 28,
#    'Vagal Maneuver': 2,
#    'ETCO2 Capnography': 13,
#    'Albuterol (Proventil)': 25,
#    'Ondansetron (Zofran)': 10,
#    'Normal saline': 30,
#    'Generic Medication Placeholder': 2,
#    'Glucose Check': 5,
#    'Nitroglycerin': 24,
#    'Adenosine (Adenocard)': 3,
#    'Dextrose': 3,
#    'Midazolam (Versed)': 2,
#    'Stabilization/Splinting': 4,
#    'Bleeding Control': 2,
#    'Ketamine (Ketalar)': 1,
#    'Patient Cooling/Warming': 1,
#    'Ipratropium (Atrovent)': 2,
#    'Vitals/Assess': 1,
#    'Nebulizer Therapy': 1,
#    'Nitroprusside (Nitropress)': 2,
#    'Fentanyl': 1,
#    'CPR': 3,
#    'Amiodarone (Cordarone)': 1,
#    'Irrigation': 1,
#    'Labetalol (Normodyne)': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 4,
#    'Move Patient': 3,
#    'Insulin': 1},
#   'ECG': {'ECG': 5180,
#    'Aspirin (ASA)': 1627,
#    'IV/IO': 1710,
#    'end': 2630,
#    'Normal saline': 62,
#    'Oxygen': 142,
#    'Monitor/Care': 15,
#    'Albuterol (Proventil)': 41,
#    'Stabilization/Splinting': 1,
#    'Vagal Maneuver': 10,
#    'Defibrillation': 6,
#    'CPAP/BiPAP': 5,
#    'Dexamethasone 10mg IV/IM': 10,
#    'Glucose Check': 4,
#    'Ondansetron (Zofran)': 30,
#    'Diphenhydramine (Benadryl)': 1,
#    'Adenosine (Adenocard)': 14,
#    'Cardioversion': 1,
#    'Nitroglycerin': 41,
#    'Fentanyl': 15,
#    'Terbutaline Sulfate 1 MG/ML': 3,
#    'Midazolam (Versed)': 3,
#    'ETCO2 Capnography': 19,
#    'Dextrose': 5,
#    'Ketorolac (Toradol)': 1,
#    'Ipratropium (Atrovent)': 1,
#    'Epinephrine 1:10,000': 1,
#    'CPR': 1,
#    'Clear Airway': 5,
#    'Nebulizer Therapy': 1,
#    'Magnesium Sulfate': 1,
#    'Dexamethasone (Decadron)': 6,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 14,
#    'Bleeding Control': 1,
#    'Amiodarone (Cordarone)': 1,
#    'Intubation': 1,
#    'Heparin': 2},
#   'Aspirin (ASA)': {'end': 670,
#    'ECG': 1281,
#    'IV/IO': 665,
#    'Normal saline': 37,
#    'Oxygen': 95,
#    'Aspirin (ASA)': 5,
#    'ETCO2 Capnography': 4,
#    'Nitroglycerin': 41,
#    'Ondansetron (Zofran)': 12,
#    'Monitor/Care': 11,
#    'Glucose Check': 1,
#    'Adenosine (Adenocard)': 1,
#    'Terbutaline Sulfate 1 MG/ML': 2,
#    'Dexamethasone 10mg IV/IM': 2,
#    'Albuterol (Proventil)': 7,
#    'Ipratropium (Atrovent)': 6,
#    'Dextrose': 2,
#    'Naloxone (Narcan)': 1,
#    'Restraint Applied': 2,
#    'Midazolam (Versed)': 1,
#    'Glutose': 2,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 7,
#    'Fentanyl': 2,
#    'Diphenhydramine (Benadryl)': 1,
#    'Dexamethasone (Decadron)': 1,
#    'Clear Airway': 1,
#    'Heparin': 1},
#   'end': {},
#   'IV/IO': {'ECG': 1303,
#    'Aspirin (ASA)': 353,
#    'end': 886,
#    'Normal saline': 76,
#    'ETCO2 Capnography': 3,
#    'IV/IO': 108,
#    'Nitroglycerin': 42,
#    'Oxygen': 47,
#    'Ondansetron (Zofran)': 59,
#    'Adenosine (Adenocard)': 12,
#    'Albuterol (Proventil)': 15,
#    'BVM': 1,
#    'Vagal Maneuver': 4,
#    'Fentanyl': 15,
#    'Dexamethasone 10mg IV/IM': 7,
#    'Terbutaline Sulfate 1 MG/ML': 1,
#    'Monitor/Care': 8,
#    'Naloxone (Narcan)': 2,
#    'Intubation': 2,
#    'Stabilization/Splinting': 1,
#    'Defibrillation': 2,
#    'Dextrose': 3,
#    'Midazolam (Versed)': 5,
#    'Glucose Check': 1,
#    'Nebulizer Therapy': 1,
#    'Epinephrine 1:10,000': 3,
#    'CPAP/BiPAP': 2,
#    'Norepinephrine (Levophed)': 1,
#    'Dextrose 10 % Injectable Solution': 2,
#    'Dexamethasone (Decadron)': 9,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 3,
#    'Magnesium Sulfate': 1,
#    'Furosemide (Lasix)': 1,
#    'Sodium Bicarbonate': 1},
#   'Normal saline': {'ECG': 44,
#    'Oxygen': 8,
#    'end': 65,
#    'IV/IO': 73,
#    'Adenosine (Adenocard)': 2,
#    'Fentanyl': 2,
#    'Aspirin (ASA)': 10,
#    'Nitroglycerin': 3,
#    'Ondansetron (Zofran)': 7,
#    'Monitor/Care': 2,
#    'Albuterol (Proventil)': 1,
#    'Midazolam (Versed)': 2,
#    'Vagal Maneuver': 1,
#    'Epinephrine 1:10,000': 1,
#    'Diphenhydramine (Benadryl)': 1},
#   'ETCO2 Capnography': {'ECG': 30,
#    'IV/IO': 13,
#    'Oxygen': 4,
#    'Aspirin (ASA)': 3,
#    'ETCO2 Capnography': 8,
#    'CPR': 1,
#    'Epinephrine 1:10,000': 1,
#    'Intubation': 1,
#    'Albuterol (Proventil)': 2,
#    'end': 8},
#   'Oxygen': {'ECG': 316,
#    'Aspirin (ASA)': 48,
#    'Nebulizer Therapy': 22,
#    'IV/IO': 84,
#    'end': 87,
#    'Intubation': 4,
#    'Oxygen': 11,
#    'ETCO2 Capnography': 20,
#    'CPR': 3,
#    'Fentanyl': 3,
#    'CPAP/BiPAP': 9,
#    'BVM': 1,
#    'Albuterol (Proventil)': 5,
#    'Normal saline': 2,
#    'Nitroglycerin': 6,
#    'Dexamethasone 10MG PO': 2,
#    'Ondansetron (Zofran)': 2,
#    'Cardioversion': 2,
#    'Naloxone (Narcan)': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1},
#   'Monitor/Care': {'end': 7, 'ECG': 55, 'Monitor/Care': 1, 'IV/IO': 3},
#   'Nitroglycerin': {'Nitroglycerin': 19,
#    'end': 53,
#    'IV/IO': 14,
#    'Ondansetron (Zofran)': 7,
#    'ECG': 67,
#    'Normal saline': 2,
#    'Oxygen': 11,
#    'Aspirin (ASA)': 6,
#    'Fentanyl': 6,
#    'Furosemide (Lasix)': 2,
#    'Dextrose': 1,
#    'Dexamethasone (Decadron)': 1},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 79,
#    'Dexamethasone 10mg IV/IM': 3,
#    'Aspirin (ASA)': 8,
#    'Oxygen': 1,
#    'end': 6,
#    'IV/IO': 1,
#    'Dexamethasone 10MG PO': 1,
#    'Dexamethasone (Decadron)': 1},
#   'Ipratropium (Atrovent)': {'Oxygen': 58,
#    'ECG': 15,
#    'IV/IO': 6,
#    'Dexamethasone 10mg IV/IM': 1,
#    'end': 6,
#    'Aspirin (ASA)': 4,
#    'Nitroglycerin': 1,
#    'CPAP/BiPAP': 1},
#   'Nebulizer Therapy': {'ECG': 17,
#    'Dexamethasone 10mg IV/IM': 2,
#    'IV/IO': 2,
#    'end': 3,
#    'Aspirin (ASA)': 1},
#   'Ondansetron (Zofran)': {'end': 67,
#    'IV/IO': 5,
#    'Oxygen': 3,
#    'ECG': 35,
#    'Normal saline': 7,
#    'Aspirin (ASA)': 7,
#    'Adenosine (Adenocard)': 1,
#    'Nitroglycerin': 5,
#    'Morphine': 1,
#    'Fentanyl': 2,
#    'Ondansetron (Zofran)': 1},
#   'Stabilization/Splinting': {'end': 2, 'ECG': 4},
#   'Vagal Maneuver': {'ECG': 7,
#    'IV/IO': 6,
#    'Adenosine (Adenocard)': 2,
#    'Normal saline': 2},
#   'Adenosine (Adenocard)': {'ECG': 22,
#    'Diphenhydramine (Benadryl)': 1,
#    'Adenosine (Adenocard)': 10,
#    'end': 6,
#    'IV/IO': 1,
#    'Oxygen': 2,
#    'Normal saline': 1,
#    'Cardioversion': 1,
#    'Midazolam (Versed)': 1},
#   'Defibrillation': {'ECG': 8,
#    'Defibrillation': 5,
#    'end': 3,
#    'CPR': 1,
#    'IV/IO': 1,
#    'Normal saline': 1,
#    'Amiodarone (Cordarone)': 1},
#   'CPAP/BiPAP': {'Nitroglycerin': 2,
#    'ECG': 6,
#    'Magnesium Sulfate': 1,
#    'IV/IO': 3,
#    'Albuterol (Proventil)': 1,
#    'end': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 2,
#    'Oxygen': 1,
#    'Dexamethasone (Decadron)': 1},
#   'Dexamethasone 10mg IV/IM': {'end': 15,
#    'Ipratropium (Atrovent)': 4,
#    'ECG': 3,
#    'Terbutaline Sulfate 1 MG/ML': 1,
#    'CPAP/BiPAP': 1,
#    'Magnesium Sulfate': 1,
#    'Albuterol (Proventil)': 1},
#   'Intubation': {'CPR': 1,
#    'BVM': 5,
#    'Epinephrine 1:10,000': 3,
#    'Defibrillation': 1,
#    'IV/IO': 3},
#   'CPR': {'IV/IO': 3,
#    'BVM': 1,
#    'Oxygen': 2,
#    'Defibrillation': 1,
#    'Intubation': 1,
#    'Epinephrine 1:10,000': 1,
#    'ECG': 2,
#    'end': 1},
#   'BVM': {'end': 1,
#    'Naloxone (Narcan)': 1,
#    'IV/IO': 1,
#    'Intubation': 1,
#    'ETCO2 Capnography': 2,
#    'Epinephrine 1:10,000': 1,
#    'Oxygen': 1},
#   'Glucose Check': {'ECG': 7, 'end': 3, 'IV/IO': 1},
#   'Diphenhydramine (Benadryl)': {'ECG': 1, 'Epinephrine 1:1,000': 1, 'end': 2},
#   'Epinephrine 1:1,000': {'end': 1},
#   'Cardioversion': {'Defibrillation': 1, 'ECG': 2, 'end': 1},
#   'Fentanyl': {'Ondansetron (Zofran)': 6,
#    'Normal saline': 1,
#    'end': 21,
#    'ECG': 9,
#    'Fentanyl': 2,
#    'Oxygen': 4,
#    'Monitor/Care': 1,
#    'IV/IO': 1,
#    'Nitroglycerin': 2,
#    'Midazolam (Versed)': 1},
#   'Terbutaline Sulfate 1 MG/ML': {'Oxygen': 1,
#    'end': 2,
#    'IV/IO': 2,
#    'Dexamethasone 10mg IV/IM': 1,
#    'ECG': 1},
#   'Naloxone (Narcan)': {'ECG': 1,
#    'end': 4,
#    'Epinephrine 1:10,000': 1,
#    'Gastric Tube Insertion': 1,
#    'Naloxone (Narcan)': 1},
#   'Midazolam (Versed)': {'Oxygen': 4,
#    'ECG': 3,
#    'end': 4,
#    'Normal saline': 1,
#    'Defibrillation': 1,
#    'IV/IO': 2,
#    'Haldol': 1},
#   'Generic Medication Placeholder': {'ECG': 1, 'Nitroglycerin': 1},
#   'Dextrose': {'ECG': 6, 'end': 7, 'Dextrose': 2, 'IV/IO': 1},
#   'Epinephrine 1:10,000': {'Naloxone (Narcan)': 2,
#    'end': 4,
#    'Defibrillation': 3,
#    'Intubation': 1,
#    'Epinephrine 1:10,000': 3,
#    'Clear Airway': 2,
#    'CPR': 1,
#    'Sodium Bicarbonate': 1,
#    'ROSC': 1},
#   'Gastric Tube Insertion': {'Epinephrine 1:10,000': 1},
#   'Bleeding Control': {'ECG': 3},
#   'Ketamine (Ketalar)': {'ECG': 1},
#   'Morphine': {'ECG': 1},
#   'Restraint Applied': {'ECG': 1, 'end': 1},
#   'Amiodarone (Cordarone)': {'Epinephrine 1:10,000': 1,
#    'Midazolam (Versed)': 1,
#    'end': 1},
#   'Patient Cooling/Warming': {'ECG': 1},
#   'Ketorolac (Toradol)': {'Aspirin (ASA)': 1},
#   'Magnesium Sulfate': {'end': 2,
#    'ECG': 1,
#    'IV/IO': 1,
#    'Albuterol (Proventil)': 1},
#   'Vitals/Assess': {'ECG': 1},
#   'Nitroprusside (Nitropress)': {'ECG': 2},
#   'Clear Airway': {'Epinephrine 1:10,000': 1,
#    'Oxygen': 2,
#    'Clear Airway': 1,
#    'ECG': 3,
#    'Intubation': 2,
#    'end': 1},
#   'Dexamethasone 10MG PO': {'end': 1, 'ECG': 2},
#   'Irrigation': {'ECG': 1},
#   'Sodium Bicarbonate': {'Clear Airway': 1, 'ECG': 1},
#   'Haldol': {'Oxygen': 1},
#   'Labetalol (Normodyne)': {'Aspirin (ASA)': 1},
#   'Norepinephrine (Levophed)': {'end': 1},
#   'Dextrose 10 % Injectable Solution': {'end': 1, 'ECG': 1},
#   'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': {'ECG': 17,
#    'IV/IO': 6,
#    'end': 1,
#    'Oxygen': 6,
#    'Aspirin (ASA)': 1,
#    'Dexamethasone (Decadron)': 1},
#   'Dexamethasone (Decadron)': {'end': 10,
#    'Aspirin (ASA)': 1,
#    'Magnesium Sulfate': 1,
#    'ECG': 3,
#    'ETCO2 Capnography': 2,
#    'Oxygen': 1,
#    'Albuterol (Proventil)': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1},
#   'Glutose': {'IV/IO': 1, 'ECG': 1},
#   'Furosemide (Lasix)': {'ECG': 1, 'Nitroglycerin': 1, 'end': 1},
#   'Move Patient': {'ECG': 3},
#   'Insulin': {'Aspirin (ASA)': 1},
#   'ROSC': {'CPR': 1},
#   'Heparin': {'Nitroglycerin': 1, 'end': 1, 'Oxygen': 1}},
#  'Chest Pain (STEMI MI)': {'start': {'ETCO2 Capnography': 2,
#    'ECG': 308,
#    'IV/IO': 38,
#    'Aspirin (ASA)': 72,
#    'Oxygen': 38,
#    'Monitor/Care': 6,
#    'Normal saline': 9,
#    'Stabilization/Splinting': 1,
#    'Restraint Applied': 2,
#    'BVM': 1,
#    'Ketamine (Ketalar)': 1,
#    'CPR': 2,
#    'Nitroglycerin': 8,
#    'Vitals/Assess': 1,
#    'Fentanyl': 1,
#    'Naloxone (Narcan)': 1,
#    'Generic Medication Placeholder': 1,
#    'Clear Airway': 1,
#    'Albuterol (Proventil)': 1,
#    'Move Patient': 1,
#    'Intubation': 1,
#    'Heparin': 1},
#   'ETCO2 Capnography': {'IV/IO': 9,
#    'Intubation': 1,
#    'Aspirin (ASA)': 1,
#    'ECG': 1,
#    'CPAP/BiPAP': 1,
#    'ETCO2 Capnography': 1,
#    'end': 1},
#   'IV/IO': {'ECG': 239,
#    'Nitroglycerin': 15,
#    'end': 68,
#    'Aspirin (ASA)': 28,
#    'Oxygen': 8,
#    'IV/IO': 27,
#    'Normal saline': 17,
#    'Fentanyl': 7,
#    'Naloxone (Narcan)': 1,
#    'Epinephrine 1:10,000': 5,
#    'Ondansetron (Zofran)': 7,
#    'CPR': 2,
#    'Midazolam (Versed)': 1,
#    'Defibrillation': 2,
#    'Monitor/Care': 2,
#    'Dextrose': 1,
#    'CPAP/BiPAP': 1,
#    'BVM': 1,
#    'Dexamethasone (Decadron)': 1,
#    'Adenosine (Adenocard)': 1,
#    'Amiodarone (Cordarone)': 1,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Albuterol (Proventil)': 1,
#    'Epinephrine 1:1,000': 1},
#   'ECG': {'ECG': 699,
#    'end': 309,
#    'IV/IO': 220,
#    'Aspirin (ASA)': 180,
#    'Normal saline': 20,
#    'Oxygen': 27,
#    'Glucose Check': 1,
#    'Ondansetron (Zofran)': 4,
#    'Nitroglycerin': 18,
#    'Monitor/Care': 2,
#    'ETCO2 Capnography': 5,
#    'Dextrose': 1,
#    'CPR': 8,
#    'BVM': 2,
#    'Atropine': 1,
#    'Albuterol (Proventil)': 3,
#    'Naloxone (Narcan)': 4,
#    'Generic Medication Placeholder': 1,
#    'Vagal Maneuver': 1,
#    'Ipratropium (Atrovent)': 1,
#    'Epinephrine 1:10,000': 2,
#    'Midazolam (Versed)': 2,
#    'Intubation': 1,
#    'CPAP/BiPAP': 2,
#    'Dopamine': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1,
#    'Furosemide (Lasix)': 1,
#    'Fentanyl': 4,
#    'Glucagon (Glucagen)': 1,
#    'Heparin': 2},
#   'end': {},
#   'Nitroglycerin': {'Nitroglycerin': 4,
#    'end': 15,
#    'ECG': 26,
#    'IV/IO': 7,
#    'Fentanyl': 4,
#    'Oxygen': 10},
#   'Aspirin (ASA)': {'end': 55,
#    'Normal saline': 9,
#    'ECG': 117,
#    'IV/IO': 76,
#    'Oxygen': 11,
#    'Nitroglycerin': 12,
#    'Generic Medication Placeholder': 1,
#    'Monitor/Care': 2,
#    'ETCO2 Capnography': 3,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1,
#    'Heparin': 2,
#    'Enoxaparin': 1},
#   'Normal saline': {'end': 14,
#    'ECG': 16,
#    'IV/IO': 23,
#    'Oxygen': 2,
#    'Aspirin (ASA)': 4,
#    'Ondansetron (Zofran)': 1,
#    'ETCO2 Capnography': 1,
#    'Nitroglycerin': 1},
#   'Oxygen': {'ECG': 54,
#    'end': 5,
#    'CPAP/BiPAP': 2,
#    'Albuterol (Proventil)': 1,
#    'IV/IO': 18,
#    'CPR': 1,
#    'Normal saline': 3,
#    'BVM': 8,
#    'Nebulizer Therapy': 2,
#    'Fentanyl': 3,
#    'Aspirin (ASA)': 3,
#    'ETCO2 Capnography': 2,
#    'Clear Airway': 1,
#    'Oxygen': 1,
#    'Nitroglycerin': 2,
#    'Intubation': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1,
#    'Ondansetron (Zofran)': 1,
#    'Epinephrine 1:10,000': 1},
#   'Monitor/Care': {'ECG': 10,
#    'IV/IO': 1,
#    'Normal saline': 1,
#    'Vitals/Assess': 1},
#   'Glucose Check': {'ECG': 1},
#   'Ondansetron (Zofran)': {'end': 9,
#    'ECG': 6,
#    'Nitroglycerin': 1,
#    'Oxygen': 1,
#    'Normal saline': 1},
#   'CPAP/BiPAP': {'ECG': 5, 'IV/IO': 1, 'Nitroglycerin': 1},
#   'Fentanyl': {'end': 6,
#    'ECG': 3,
#    'Monitor/Care': 1,
#    'Normal saline': 1,
#    'Ondansetron (Zofran)': 3,
#    'Oxygen': 1,
#    'Nitroglycerin': 3,
#    'IV/IO': 1,
#    'Fentanyl': 1},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 4,
#    'ECG': 1,
#    'Oxygen': 1},
#   'Ipratropium (Atrovent)': {'ECG': 1,
#    'Oxygen': 2,
#    'IV/IO': 1,
#    'Aspirin (ASA)': 1},
#   'Stabilization/Splinting': {'ECG': 1},
#   'Naloxone (Narcan)': {'Cardiac Pacing': 1,
#    'Naloxone (Narcan)': 2,
#    'IV/IO': 1,
#    'ECG': 2,
#    'Intubation': 1,
#    'end': 1},
#   'Cardiac Pacing': {'end': 1},
#   'Dextrose': {'ECG': 1, 'end': 1},
#   'CPR': {'ECG': 5,
#    'IV/IO': 4,
#    'end': 1,
#    'Oxygen': 3,
#    'Defibrillation': 2,
#    'Epinephrine 1:10,000': 2,
#    'Intubation': 1},
#   'BVM': {'CPR': 3,
#    'end': 1,
#    'ECG': 5,
#    'IV/IO': 3,
#    'Defibrillation': 2,
#    'Intubation': 1,
#    'Epinephrine 1:10,000': 1,
#    'Normal saline': 1},
#   'Epinephrine 1:10,000': {'Epinephrine 1:10,000': 6,
#    'ETCO2 Capnography': 1,
#    'Defibrillation': 2,
#    'Clear Airway': 1,
#    'end': 3,
#    'Intubation': 2,
#    'ROSC': 3,
#    'ECG': 1,
#    'Oxygen': 1},
#   'Intubation': {'Intubation': 1,
#    'BVM': 5,
#    'IV/IO': 3,
#    'Epinephrine 1:10,000': 3,
#    'ECG': 2,
#    'Atropine': 1},
#   'Atropine': {'ECG': 1, 'Epinephrine 1:1,000': 1, 'end': 1},
#   'Nebulizer Therapy': {'ECG': 1, 'Aspirin (ASA)': 1},
#   'Restraint Applied': {'Oxygen': 1, 'ECG': 1},
#   'Generic Medication Placeholder': {'Ondansetron (Zofran)': 1,
#    'end': 1,
#    'ECG': 1},
#   'Ketamine (Ketalar)': {'ECG': 1},
#   'Defibrillation': {'CPR': 1,
#    'IV/IO': 2,
#    'Intubation': 2,
#    'ECG': 3,
#    'Defibrillation': 1},
#   'Clear Airway': {'Intubation': 2, 'ECG': 1, 'CPR': 1},
#   'Vagal Maneuver': {'ECG': 1},
#   'Midazolam (Versed)': {'ECG': 1, 'IV/IO': 2},
#   'Vitals/Assess': {'ECG': 2},
#   'Dopamine': {'ECG': 1},
#   'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': {'end': 1,
#    'ECG': 1,
#    'CPAP/BiPAP': 1},
#   'Furosemide (Lasix)': {'end': 1},
#   'Dexamethasone (Decadron)': {'Magnesium Sulfate': 1},
#   'Magnesium Sulfate': {'ECG': 1},
#   'ROSC': {'Gastric Tube Insertion': 1, 'end': 1, 'ECG': 1},
#   'Gastric Tube Insertion': {'Clear Airway': 1},
#   'Adenosine (Adenocard)': {'Adenosine (Adenocard)': 1, 'IV/IO': 1},
#   'Amiodarone (Cordarone)': {'Ondansetron (Zofran)': 1},
#   'Move Patient': {'ECG': 1},
#   'Dextrose 10 % Injectable Solution': {'ECG': 1},
#   'Heparin': {'Nitroglycerin': 1, 'Oxygen': 2, 'end': 1, 'ECG': 1},
#   'Glucagon (Glucagen)': {'end': 1},
#   'Epinephrine 1:1,000': {'Intubation': 1,
#    'Epinephrine 1:1,000': 1,
#    'Atropine': 1},
#   'Enoxaparin': {'Oxygen': 1}},
#  'Cardiac Arrest': {'start': {'ECG': 82,
#    'CPR': 281,
#    'Oxygen': 201,
#    'ETCO2 Capnography': 9,
#    'BVM': 73,
#    'Intubation': 111,
#    'IV/IO': 36,
#    'Epinephrine 1:10,000': 43,
#    'Naloxone (Narcan)': 6,
#    'Normal saline': 19,
#    'Gastric Tube Insertion': 1,
#    'Defibrillation': 14,
#    'Aspirin (ASA)': 3,
#    'Thoracostomy': 1,
#    'Clear Airway': 7,
#    'Monitor/Care': 2,
#    'Open/Position Airway': 6,
#    'Amiodarone (Cordarone)': 4,
#    'Epinephrine 1:1,000': 2,
#    'Sodium Bicarbonate': 1,
#    'Albuterol (Proventil)': 1,
#    '10 ML calcium chloride 10 % Prefilled Syringe': 1,
#    'Stabilization/Splinting': 2,
#    'Cardiac Pacing': 4,
#    'Move Patient': 1,
#    'Bleeding Control': 1,
#    'CYANOKIT 5g': 1,
#    'Midazolam (Versed)': 1},
#   'ECG': {'CPR': 170,
#    'Epinephrine 1:10,000': 124,
#    'IV/IO': 217,
#    'end': 132,
#    'ECG': 178,
#    'Clear Airway': 22,
#    'BVM': 27,
#    'Oxygen': 39,
#    'Intubation': 67,
#    'Midazolam (Versed)': 6,
#    'ETCO2 Capnography': 19,
#    'Cardiac Pacing': 1,
#    'Defibrillation': 38,
#    '1745278': 2,
#    'Amiodarone (Cordarone)': 5,
#    'Naloxone (Narcan)': 10,
#    'Norepinephrine (Levophed)': 3,
#    'Normal saline': 18,
#    'Atropine': 1,
#    'Thoracostomy': 3,
#    'Nitroglycerin': 1,
#    'Epinephrine 1:1,000': 1,
#    'Open/Position Airway': 3,
#    'Albuterol (Proventil)': 1,
#    'Gastric Tube Insertion': 2,
#    'Sodium Bicarbonate': 3,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Stabilization/Splinting': 1,
#    'ROSC': 4},
#   'CPR': {'Intubation': 136,
#    'IV/IO': 243,
#    'BVM': 192,
#    'ECG': 183,
#    'CPR': 122,
#    'Defibrillation': 50,
#    'Epinephrine 1:10,000': 144,
#    'ETCO2 Capnography': 15,
#    'end': 23,
#    'Oxygen': 124,
#    'Clear Airway': 28,
#    'Gastric Tube Insertion': 4,
#    'Monitor/Care': 4,
#    'Stabilization/Splinting': 3,
#    'Normal saline': 13,
#    'Sodium Bicarbonate': 2,
#    'Naloxone (Narcan)': 9,
#    'Open/Position Airway': 7,
#    'Epinephrine 1:1,000': 2,
#    'Move Patient': 2,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Amiodarone (Cordarone)': 4,
#    'Access Airway': 1,
#    'ROSC': 4,
#    'Thoracostomy': 1},
#   'Intubation': {'IV/IO': 170,
#    'Epinephrine 1:10,000': 291,
#    'Intubation': 69,
#    'Naloxone (Narcan)': 15,
#    'ETCO2 Capnography': 64,
#    'BVM': 173,
#    'CPR': 143,
#    'Clear Airway': 45,
#    'Gastric Tube Insertion': 16,
#    'Oxygen': 41,
#    'end': 18,
#    'Sodium Bicarbonate': 12,
#    'ECG': 76,
#    'Midazolam (Versed)': 4,
#    'Defibrillation': 42,
#    'Normal saline': 12,
#    'Epinephrine 1:1,000': 3,
#    'Glucose Check': 1,
#    'Monitor/Care': 1,
#    'Vitals/Assess': 1,
#    'Nitroglycerin': 1,
#    'Amiodarone (Cordarone)': 6,
#    'CPR Discontinued': 1,
#    'Dextrose 10 % Injectable Solution': 4,
#    'Move Patient': 3,
#    'Open/Position Airway': 2,
#    'Extrication': 1,
#    'ROSC': 5,
#    'Stabilization/Splinting': 2,
#    'Norepinephrine (Levophed)': 1,
#    'Atropine': 1},
#   'IV/IO': {'CPR': 40,
#    'IV/IO': 103,
#    'Epinephrine 1:10,000': 519,
#    'ECG': 84,
#    'Normal saline': 69,
#    'Intubation': 95,
#    'BVM': 46,
#    'Sodium Bicarbonate': 3,
#    'Glucose Check': 1,
#    'Clear Airway': 13,
#    'Naloxone (Narcan)': 24,
#    'Norepinephrine (Levophed)': 3,
#    'ETCO2 Capnography': 14,
#    'Amiodarone (Cordarone)': 10,
#    'Defibrillation': 36,
#    'Oxygen': 17,
#    'end': 23,
#    'Thoracostomy': 2,
#    'Monitor/Care': 3,
#    'Epinephrine 1:1,000': 7,
#    '10 ML calcium chloride 10 % Prefilled Syringe': 1,
#    'Dexamethasone 10mg IV/IM': 1,
#    'Vagal Maneuver': 1,
#    'Dextrose 10 % Injectable Solution': 1,
#    'CPR Discontinued': 1,
#    'Calcium Chloride': 1,
#    'Atropine': 2,
#    'ROSC': 3,
#    'Gastric Tube Insertion': 2,
#    'CPAP/BiPAP': 1,
#    'Midazolam (Versed)': 1,
#    'Magnesium Sulfate': 1},
#   'Epinephrine 1:10,000': {'IV/IO': 60,
#    'end': 455,
#    'Epinephrine 1:10,000': 740,
#    'Intubation': 303,
#    'Sodium Bicarbonate': 129,
#    'ECG': 121,
#    'Normal saline': 73,
#    'BVM': 12,
#    'Clear Airway': 73,
#    'CPR': 77,
#    'Dextrose 10 % Injectable Solution': 25,
#    'CPR Discontinued': 20,
#    'Naloxone (Narcan)': 161,
#    'ETCO2 Capnography': 77,
#    '10 ML calcium chloride 10 % Prefilled Syringe': 12,
#    'Defibrillation': 167,
#    'Amiodarone (Cordarone)': 60,
#    'Oxygen': 24,
#    'Access Airway': 1,
#    'Thoracostomy': 4,
#    'Gastric Tube Insertion': 16,
#    'Monitor/Care': 8,
#    'Atropine': 4,
#    'Norepinephrine (Levophed)': 2,
#    'Stabilization/Splinting': 5,
#    'Epinephrine 1:1,000': 2,
#    '1745278': 1,
#    'Open/Position Airway': 2,
#    'Glucose Check': 1,
#    'Move Patient': 1,
#    'Magnesium Sulfate': 1,
#    'Diphenhydramine (Benadryl)': 1,
#    'Calcium Gluconate 100 MG/ML Injectable Solution': 2,
#    'Midazolam (Versed)': 1,
#    'ROSC': 48,
#    '0': 1,
#    'Albuterol (Proventil)': 1,
#    'Calcium Chloride': 5,
#    'Cricothyrotomy': 1},
#   'end': {},
#   'BVM': {'Naloxone (Narcan)': 7,
#    'CPR': 192,
#    'Intubation': 92,
#    'Oxygen': 37,
#    'ECG': 136,
#    'Defibrillation': 35,
#    'ETCO2 Capnography': 30,
#    'Epinephrine 1:10,000': 81,
#    'IV/IO': 77,
#    'Move Patient': 2,
#    'Normal saline': 10,
#    'end': 13,
#    'Gastric Tube Insertion': 3,
#    'Clear Airway': 16,
#    'Amiodarone (Cordarone)': 3,
#    'BVM': 6,
#    'Sodium Bicarbonate': 2,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Epinephrine 1:1,000': 2,
#    'Stabilization/Splinting': 1,
#    'Glucose Check': 1,
#    'Monitor/Care': 1,
#    'CPR Discontinued': 1,
#    'Restraint Applied': 1,
#    'Atropine': 1,
#    'Open/Position Airway': 2},
#   'Naloxone (Narcan)': {'IV/IO': 4,
#    'Dextrose 10 % Injectable Solution': 5,
#    'Naloxone (Narcan)': 5,
#    'Epinephrine 1:10,000': 116,
#    'Sodium Bicarbonate': 15,
#    'end': 13,
#    'Defibrillation': 11,
#    'ECG': 14,
#    'Oxygen': 9,
#    'Epinephrine 1:1,000': 2,
#    'Normal saline': 9,
#    'CPR': 5,
#    'Intubation': 33,
#    'ETCO2 Capnography': 6,
#    'Cardiac Pacing': 1,
#    'Clear Airway': 10,
#    'Amiodarone (Cordarone)': 2,
#    'BVM': 2,
#    'Gastric Tube Insertion': 3,
#    'Ondansetron (Zofran)': 1,
#    'Stabilization/Splinting': 1,
#    'CPR Discontinued': 2,
#    'ROSC': 5,
#    'Calcium Chloride': 1},
#   'Oxygen': {'BVM': 167,
#    'CPAP/BiPAP': 3,
#    'CPR': 126,
#    'ECG': 57,
#    'Intubation': 78,
#    'IV/IO': 35,
#    'Epinephrine 1:10,000': 10,
#    'Clear Airway': 15,
#    'Stabilization/Splinting': 3,
#    'Atropine': 1,
#    'ETCO2 Capnography': 12,
#    'Bleeding Control': 1,
#    'end': 7,
#    'Normal saline': 4,
#    'Naloxone (Narcan)': 1,
#    'Defibrillation': 11,
#    'Monitor/Care': 1,
#    'Oxygen': 2,
#    'Open/Position Airway': 5,
#    'Propofol Injection (Diprivan)': 1,
#    'Sodium Bicarbonate': 1},
#   'Dextrose 10 % Injectable Solution': {'ECG': 3,
#    'Intubation': 6,
#    'Normal saline': 1,
#    'Naloxone (Narcan)': 1,
#    'Epinephrine 1:10,000': 26,
#    'Clear Airway': 3,
#    'end': 4,
#    'CPR Discontinued': 1,
#    'Sodium Bicarbonate': 2,
#    'ETCO2 Capnography': 1},
#   'Sodium Bicarbonate': {'Intubation': 13,
#    'end': 23,
#    'Epinephrine 1:10,000': 102,
#    'ECG': 5,
#    'Oxygen': 2,
#    'Normal saline': 2,
#    'CPR Discontinued': 2,
#    'Naloxone (Narcan)': 5,
#    'Defibrillation': 8,
#    '10 ML calcium chloride 10 % Prefilled Syringe': 2,
#    'IV/IO': 3,
#    'Clear Airway': 5,
#    'CPR': 2,
#    'Dextrose 10 % Injectable Solution': 2,
#    'Open/Position Airway': 2,
#    'Monitor/Care': 1,
#    'ETCO2 Capnography': 3,
#    'ROSC': 6,
#    'Calcium Chloride': 1},
#   'ETCO2 Capnography': {'Intubation': 62,
#    'CPR': 24,
#    'Gastric Tube Insertion': 8,
#    'IV/IO': 29,
#    'Defibrillation': 14,
#    'BVM': 18,
#    'Oxygen': 3,
#    'Epinephrine 1:10,000': 61,
#    'Epinephrine 1:1,000': 1,
#    'Dextrose 10 % Injectable Solution': 4,
#    'end': 22,
#    'Clear Airway': 7,
#    'Normal saline': 2,
#    'Sodium Bicarbonate': 4,
#    'Cricothyrotomy': 1,
#    'ECG': 18,
#    'ETCO2 Capnography': 14,
#    'Naloxone (Narcan)': 4,
#    'Norepinephrine (Levophed)': 1,
#    'CPAP/BiPAP': 1,
#    'ROSC': 3,
#    'Atropine': 1},
#   'Normal saline': {'Intubation': 35,
#    'Epinephrine 1:10,000': 71,
#    'CPR': 12,
#    'ECG': 22,
#    'ETCO2 Capnography': 6,
#    'BVM': 4,
#    'Thoracostomy': 1,
#    'Naloxone (Narcan)': 9,
#    'Clear Airway': 4,
#    'Oxygen': 16,
#    'Amiodarone (Cordarone)': 3,
#    'IV/IO': 37,
#    'Atropine': 1,
#    'end': 16,
#    'Glucose Check': 1,
#    'Gastric Tube Insertion': 1,
#    'Defibrillation': 4,
#    'Sodium Bicarbonate': 1,
#    'CPR Discontinued': 1,
#    'Propofol (Diprivan)': 1},
#   'CPAP/BiPAP': {'CPR': 1,
#    'ECG': 2,
#    'Oxygen': 1,
#    'end': 1,
#    'ETCO2 Capnography': 1},
#   'Defibrillation': {'BVM': 14,
#    'CPR': 45,
#    'Epinephrine 1:10,000': 143,
#    'end': 53,
#    'ECG': 28,
#    'Naloxone (Narcan)': 9,
#    'Clear Airway': 7,
#    'IV/IO': 60,
#    'ETCO2 Capnography': 6,
#    'Defibrillation': 72,
#    'Amiodarone (Cordarone)': 73,
#    'Oxygen': 9,
#    'Intubation': 20,
#    'Normal saline': 4,
#    '10 ML calcium chloride 10 % Prefilled Syringe': 2,
#    'Epinephrine 1:1,000': 3,
#    'Monitor/Care': 1,
#    'Atropine': 1,
#    'Midazolam (Versed)': 1,
#    'Magnesium Sulfate': 2,
#    'Sodium Bicarbonate': 2,
#    'ROSC': 7,
#    'Gastric Tube Insertion': 1,
#    'CPR Discontinued': 2},
#   'Clear Airway': {'Intubation': 60,
#    'BVM': 12,
#    'Normal saline': 2,
#    'Epinephrine 1:10,000': 76,
#    'ECG': 19,
#    'Clear Airway': 5,
#    'CPR': 23,
#    'IV/IO': 26,
#    'end': 14,
#    'ETCO2 Capnography': 11,
#    'CPR Discontinued': 1,
#    'Gastric Tube Insertion': 6,
#    'Sodium Bicarbonate': 3,
#    'Oxygen': 4,
#    'Amiodarone (Cordarone)': 3,
#    'Epinephrine 1:1,000': 1,
#    'Defibrillation': 4,
#    'ROSC': 4,
#    'Bleeding Control': 1,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Fentanyl': 1,
#    'Naloxone (Narcan)': 1},
#   'Gastric Tube Insertion': {'CPR': 6,
#    'Epinephrine 1:10,000': 29,
#    'end': 2,
#    'ECG': 5,
#    'Sodium Bicarbonate': 1,
#    'IV/IO': 3,
#    'Naloxone (Narcan)': 2,
#    'Clear Airway': 9,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Normal saline': 1,
#    'Amiodarone (Cordarone)': 2,
#    'Intubation': 1,
#    'Stabilization/Splinting': 1,
#    'ETCO2 Capnography': 1,
#    'ROSC': 1,
#    'Midazolam (Versed)': 1,
#    'Defibrillation': 1},
#   'CPR Discontinued': {'end': 27,
#    'ECG': 1,
#    'CPR': 1,
#    'Epinephrine 1:10,000': 1,
#    'ROSC': 2},
#   'Midazolam (Versed)': {'end': 6,
#    'ECG': 8,
#    'Haldol': 1,
#    'IV/IO': 2,
#    'Cardioversion': 1,
#    'CPR': 1},
#   '10 ML calcium chloride 10 % Prefilled Syringe': {'Intubation': 1,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Epinephrine 1:10,000': 10,
#    'Defibrillation': 1,
#    'end': 2,
#    'ECG': 1,
#    'Sodium Bicarbonate': 2},
#   'Move Patient': {'CPR': 2,
#    'ECG': 1,
#    'Intubation': 3,
#    'Defibrillation': 1,
#    'BVM': 1,
#    'Oxygen': 1},
#   'Amiodarone (Cordarone)': {'end': 18,
#    'Epinephrine 1:10,000': 66,
#    'Intubation': 10,
#    'Defibrillation': 44,
#    'Normal saline': 1,
#    'Midazolam (Versed)': 2,
#    'Gastric Tube Insertion': 2,
#    'ECG': 12,
#    'Norepinephrine (Levophed)': 1,
#    'ETCO2 Capnography': 8,
#    'Sodium Bicarbonate': 3,
#    'Naloxone (Narcan)': 3,
#    'CPR': 4,
#    'Epinephrine 1:1,000': 2,
#    'Clear Airway': 2,
#    'Oxygen': 2,
#    'ROSC': 2,
#    'IV/IO': 1},
#   'Glucose Check': {'Intubation': 1,
#    'Epinephrine 1:1,000': 1,
#    'Epinephrine 1:10,000': 2,
#    'BVM': 1},
#   'Epinephrine 1:1,000': {'Epinephrine 1:1,000': 4,
#    'Naloxone (Narcan)': 2,
#    'ETCO2 Capnography': 1,
#    'Gastric Tube Insertion': 1,
#    'end': 6,
#    'Epinephrine 1:10,000': 4,
#    'Intubation': 5,
#    'Defibrillation': 3,
#    'Amiodarone (Cordarone)': 3,
#    'Insulin': 1,
#    'Sodium Bicarbonate': 1,
#    'IV/IO': 1,
#    'Oxygen': 1,
#    'Atropine': 1},
#   'Stabilization/Splinting': {'ECG': 4,
#    'IV/IO': 1,
#    'BVM': 2,
#    'Sodium Bicarbonate': 1,
#    'Defibrillation': 1,
#    'Access Airway': 1,
#    'Intubation': 2,
#    'Stabilization/Splinting': 1,
#    'end': 1,
#    'Epinephrine 1:10,000': 4,
#    'ROSC': 2,
#    'Thoracostomy': 1},
#   'Access Airway': {'Epinephrine 1:10,000': 1,
#    'Oxygen': 1,
#    'ETCO2 Capnography': 1},
#   'Thoracostomy': {'Normal saline': 1,
#    'Epinephrine 1:10,000': 6,
#    'IV/IO': 2,
#    'ETCO2 Capnography': 1,
#    'Thoracostomy': 3,
#    'CPR': 2,
#    'Intubation': 1},
#   'Atropine': {'end': 3,
#    'ECG': 3,
#    'CPR': 6,
#    'Cardiac Pacing': 1,
#    'Atropine': 3,
#    'Epinephrine 1:10,000': 2,
#    'ROSC': 1,
#    'IV/IO': 1,
#    'Normal saline': 1,
#    'Defibrillation': 1,
#    'Epinephrine 1:1,000': 1},
#   'Monitor/Care': {'ETCO2 Capnography': 1,
#    'IV/IO': 5,
#    'Monitor/Care': 10,
#    'end': 4,
#    'Intubation': 3,
#    'Epinephrine 1:10,000': 5,
#    'CPR': 1,
#    'Clear Airway': 1,
#    'Defibrillation': 1,
#    'Oxygen': 1},
#   'Norepinephrine (Levophed)': {'Epinephrine 1:10,000': 1,
#    'end': 3,
#    'Amiodarone (Cordarone)': 1,
#    'Cardiac Pacing': 1,
#    'ECG': 3,
#    'Normal saline': 1,
#    'Intubation': 1,
#    'CPR': 1},
#   'Cardiac Pacing': {'end': 2,
#    'ECG': 1,
#    'CPR': 1,
#    'Intubation': 2,
#    'Oxygen': 2},
#   'Bleeding Control': {'Wound Care': 1, 'end': 1, 'ECG': 1},
#   'Wound Care': {'CPR': 1},
#   '1745278': {'Midazolam (Versed)': 1, 'end': 1, 'Normal saline': 1},
#   'Cricothyrotomy': {'Epinephrine 1:10,000': 1, 'Defibrillation': 1},
#   'Aspirin (ASA)': {'ECG': 1, 'Oxygen': 1, 'IV/IO': 1},
#   'Vitals/Assess': {'CPR': 1},
#   'Ondansetron (Zofran)': {'IV/IO': 1},
#   'Nitroglycerin': {'BVM': 1, 'end': 1, 'ECG': 1},
#   'Haldol': {'Oxygen': 1},
#   'Open/Position Airway': {'Epinephrine 1:10,000': 1,
#    'CPR': 15,
#    'ECG': 4,
#    'IV/IO': 2,
#    'Oxygen': 1,
#    'Defibrillation': 1,
#    'Clear Airway': 2,
#    'Intubation': 2,
#    'BVM': 1},
#   'Insulin': {'Intubation': 1},
#   'Magnesium Sulfate': {'Epinephrine 1:10,000': 3,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Intubation': 1},
#   'Diphenhydramine (Benadryl)': {'Epinephrine 1:10,000': 1},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 3},
#   'Ipratropium (Atrovent)': {'ECG': 1, 'IV/IO': 1, 'Epinephrine 1:10,000': 1},
#   'Dexamethasone 10mg IV/IM': {'CPAP/BiPAP': 1},
#   'Extrication': {'Intubation': 1},
#   'Calcium Gluconate 100 MG/ML Injectable Solution': {'Epinephrine 1:10,000': 1,
#    'Normal saline': 1},
#   'Propofol Injection (Diprivan)': {'Nitroglycerin': 1},
#   'Restraint Applied': {'IV/IO': 1},
#   'Vagal Maneuver': {'ECG': 1},
#   'Cardioversion': {'Defibrillation': 1, 'Amiodarone (Cordarone)': 1},
#   'ROSC': {'ECG': 22,
#    'CPR': 12,
#    'Defibrillation': 3,
#    'Clear Airway': 4,
#    'Stabilization/Splinting': 1,
#    'IV/IO': 6,
#    'BVM': 1,
#    'Oxygen': 1,
#    'end': 19,
#    'Naloxone (Narcan)': 1,
#    'Atropine': 6,
#    'Intubation': 7,
#    'Epinephrine 1:10,000': 6,
#    'Gastric Tube Insertion': 1,
#    'Amiodarone (Cordarone)': 3,
#    'Cardioversion': 1,
#    'ETCO2 Capnography': 1,
#    'Normal saline': 1,
#    'Magnesium Sulfate': 1,
#    'Norepinephrine (Levophed)': 1},
#   '0': {'end': 1},
#   'Calcium Chloride': {'Epinephrine 1:10,000': 5,
#    'Intubation': 1,
#    'ROSC': 1,
#    'Sodium Bicarbonate': 1},
#   'Propofol (Diprivan)': {'Intubation': 1},
#   'Fentanyl': {'Midazolam (Versed)': 1},
#   'CYANOKIT 5g': {'ECG': 1}},
#  'Hypoglycemia': {'start': {'IV/IO': 319,
#    'Stabilization/Splinting': 3,
#    'Oxygen': 53,
#    'Dextrose 10 % Injectable Solution': 93,
#    'ECG': 328,
#    'Dextrose': 221,
#    'Glucose Check': 5,
#    'BVM': 4,
#    'Bleeding Control': 2,
#    'Aspirin (ASA)': 2,
#    'Intubation': 4,
#    'Clear Airway': 7,
#    'Dexamethasone 10mg IV/IM': 3,
#    'ETCO2 Capnography': 5,
#    'Normal saline': 4,
#    'Wound Care': 1,
#    'Monitor/Care': 3,
#    'Glucagon (Glucagen)': 20,
#    'Midazolam (Versed)': 1,
#    'Naloxone (Narcan)': 1,
#    'Patient Cooling/Warming': 3,
#    'Restraint Applied': 4,
#    'Glutose': 28,
#    'Vitals/Assess': 1,
#    'Open/Position Airway': 1,
#    'Move Patient': 1},
#   'IV/IO': {'Glucagon (Glucagen)': 73,
#    'end': 128,
#    'IV/IO': 147,
#    'Dextrose 10 % Injectable Solution': 458,
#    'ECG': 256,
#    'Dextrose': 42,
#    'Adenosine (Adenocard)': 1,
#    'BVM': 3,
#    'Glucose Check': 2,
#    'Normal saline': 9,
#    'Naloxone (Narcan)': 11,
#    'ETCO2 Capnography': 4,
#    'Oxygen': 12,
#    'Midazolam (Versed)': 1,
#    'Monitor/Care': 3,
#    'Stabilization/Splinting': 3,
#    'Restraint Applied': 3,
#    'Intubation': 4,
#    'Clear Airway': 4,
#    'Aspirin (ASA)': 1,
#    'Dextrose 50 % Injectable Solution': 3,
#    'Dextrose 25%': 3,
#    'Norepinephrine (Levophed)': 1,
#    'Glutose': 5,
#    'Ondansetron (Zofran)': 2,
#    'Fentanyl': 1,
#    'Bleeding Control': 1,
#    'Dextrose 5% in 0.45% NS': 1},
#   'Glucagon (Glucagen)': {'ECG': 48,
#    'IV/IO': 35,
#    'Oxygen': 9,
#    'end': 40,
#    'Dextrose 10 % Injectable Solution': 6,
#    'Midazolam (Versed)': 2,
#    'Dextrose': 10,
#    'Stabilization/Splinting': 1,
#    'Glutose': 1,
#    'Intubation': 2},
#   'ECG': {'end': 327,
#    'Dextrose': 78,
#    'IV/IO': 381,
#    'ECG': 329,
#    'Dextrose 10 % Injectable Solution': 121,
#    'Glucose Check': 6,
#    'Intubation': 5,
#    'Glucagon (Glucagen)': 42,
#    'Naloxone (Narcan)': 8,
#    'Oxygen': 18,
#    'Ondansetron (Zofran)': 4,
#    'ETCO2 Capnography': 7,
#    'Aspirin (ASA)': 3,
#    'Clear Airway': 6,
#    'Midazolam (Versed)': 2,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1,
#    'Patient Cooling/Warming': 2,
#    'Normal saline': 4,
#    'Monitor/Care': 2,
#    'Atropine': 1,
#    'Albuterol (Proventil)': 2,
#    'Dextrose 25%': 1,
#    'BVM': 1,
#    'Glutose': 4,
#    'Dextrose 50 % Injectable Solution': 1},
#   'end': {},
#   'Stabilization/Splinting': {'ECG': 6,
#    'end': 1,
#    'Bleeding Control': 1,
#    'Patient Cooling/Warming': 1},
#   'Dextrose': {'ECG': 87,
#    'IV/IO': 91,
#    'Dextrose': 54,
#    'Glucose Check': 3,
#    'Dextrose 10 % Injectable Solution': 6,
#    'end': 170,
#    'Normal saline': 3,
#    'Ondansetron (Zofran)': 1,
#    'Glucagon (Glucagen)': 4,
#    'Oxygen': 3,
#    'Bleeding Control': 2,
#    'Stabilization/Splinting': 1},
#   'Oxygen': {'Oxygen': 3,
#    'IV/IO': 37,
#    'ETCO2 Capnography': 6,
#    'end': 15,
#    'Intubation': 8,
#    'BVM': 7,
#    'ECG': 33,
#    'Glucagon (Glucagen)': 5,
#    'Normal saline': 2,
#    'Dextrose 10 % Injectable Solution': 8,
#    'Nebulizer Therapy': 1,
#    'Cardiac Pacing': 1,
#    'Dextrose': 2,
#    'Albuterol (Proventil)': 2,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1,
#    'Restraint Applied': 1,
#    'Midazolam (Versed)': 1},
#   'Dextrose 10 % Injectable Solution': {'ECG': 197,
#    'ETCO2 Capnography': 4,
#    'IV/IO': 110,
#    'end': 331,
#    'Normal saline': 13,
#    'Glucagon (Glucagen)': 5,
#    'Dextrose 10 % Injectable Solution': 18,
#    'Dextrose': 11,
#    'Glucose Check': 4,
#    'Clear Airway': 2,
#    'Midazolam (Versed)': 1,
#    'Intubation': 3,
#    'Oxygen': 15,
#    'Monitor/Care': 1,
#    'Naloxone (Narcan)': 5,
#    'Patient Cooling/Warming': 1,
#    'Epinephrine 1:10,000': 1,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 1,
#    'Bleeding Control': 1,
#    'Norepinephrine (Levophed)': 1},
#   'ETCO2 Capnography': {'ECG': 9,
#    'IV/IO': 10,
#    'Oxygen': 2,
#    'Naloxone (Narcan)': 2,
#    'BVM': 1,
#    'Glucose Check': 1,
#    'end': 4,
#    'Intubation': 2,
#    'Glucagon (Glucagen)': 1,
#    'ETCO2 Capnography': 2},
#   'Adenosine (Adenocard)': {'ECG': 1},
#   'Normal saline': {'IV/IO': 6,
#    'Dextrose 10 % Injectable Solution': 3,
#    'Oxygen': 2,
#    'ECG': 6,
#    'end': 20,
#    'Dextrose': 2,
#    'Ondansetron (Zofran)': 2,
#    'Glucose Check': 1,
#    'Epinephrine 1:10,000': 1},
#   'Glucose Check': {'Glucose Check': 8,
#    'end': 10,
#    'Dextrose': 1,
#    'IV/IO': 6,
#    'Dextrose 10 % Injectable Solution': 1,
#    'ECG': 3,
#    'Normal saline': 1},
#   'BVM': {'ECG': 7,
#    'Oxygen': 3,
#    'IV/IO': 5,
#    'CPR': 1,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Intubation': 1,
#    'Defibrillation': 1,
#    'Naloxone (Narcan)': 1,
#    'ETCO2 Capnography': 1},
#   'Bleeding Control': {'ECG': 3,
#    'end': 2,
#    'Stabilization/Splinting': 1,
#    'Dextrose 10 % Injectable Solution': 1},
#   'Intubation': {'IV/IO': 8,
#    'Oxygen': 5,
#    'Clear Airway': 2,
#    'ETCO2 Capnography': 3,
#    'BVM': 3,
#    'ECG': 5,
#    'CPR': 1,
#    'Ondansetron (Zofran)': 1,
#    'Normal saline': 1,
#    'Dextrose 10 % Injectable Solution': 1,
#    'end': 3},
#   'Aspirin (ASA)': {'ECG': 2, 'Dextrose': 2, 'end': 1, 'Nitroglycerin': 1},
#   'Naloxone (Narcan)': {'end': 9,
#    'Dextrose 10 % Injectable Solution': 4,
#    'ECG': 3,
#    'Epinephrine 1:10,000': 2,
#    'IV/IO': 3,
#    'BVM': 1,
#    'Normal saline': 2,
#    'Clear Airway': 1,
#    'Naloxone (Narcan)': 1,
#    'Oxygen': 2,
#    'ETCO2 Capnography': 1,
#    'Dextrose 50 % Injectable Solution': 1},
#   'Clear Airway': {'Oxygen': 2,
#    'Clear Airway': 1,
#    'end': 4,
#    'Intubation': 2,
#    'ECG': 6,
#    'Epinephrine 1:10,000': 1,
#    'IV/IO': 6,
#    'Glucagon (Glucagen)': 1,
#    'Midazolam (Versed)': 1,
#    'Dextrose 10 % Injectable Solution': 2},
#   'Dexamethasone 10mg IV/IM': {'Oxygen': 1, 'IV/IO': 1, 'ECG': 1},
#   'Ondansetron (Zofran)': {'end': 8,
#    'Fentanyl': 1,
#    'Normal saline': 1,
#    'ECG': 1},
#   'Midazolam (Versed)': {'Naloxone (Narcan)': 1,
#    'ECG': 2,
#    'Oxygen': 1,
#    'Normal saline': 1,
#    'Midazolam (Versed)': 1,
#    'Glucagon (Glucagen)': 1,
#    'end': 2,
#    'ETCO2 Capnography': 1},
#   'Monitor/Care': {'end': 2, 'ECG': 6, 'IV/IO': 1},
#   'Wound Care': {'IV/IO': 1},
#   'Fentanyl': {'end': 1, 'ECG': 1},
#   'CPR': {'BVM': 1, 'IV/IO': 1},
#   'Epinephrine 1:10,000': {'Intubation': 2,
#    'Epinephrine 1:10,000': 1,
#    'Clear Airway': 2,
#    'end': 1},
#   'Restraint Applied': {'end': 1,
#    'ECG': 3,
#    'Glucagon (Glucagen)': 1,
#    'IV/IO': 2,
#    'Dextrose': 1},
#   'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': {'Oxygen': 1,
#    'end': 1,
#    'Dextrose': 1},
#   'Nebulizer Therapy': {'Normal saline': 1},
#   'Cardiac Pacing': {'Atropine': 1},
#   'Atropine': {'Atropine': 1,
#    'Dextrose 10 % Injectable Solution': 1,
#    'Normal saline': 1},
#   'Patient Cooling/Warming': {'end': 1,
#    'IV/IO': 2,
#    'ECG': 3,
#    'Clear Airway': 1},
#   'Defibrillation': {'IV/IO': 1},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 5},
#   'Ipratropium (Atrovent)': {'Dextrose 10 % Injectable Solution': 1,
#    'end': 1,
#    'Dexamethasone (Decadron)': 2,
#    'Oxygen': 1},
#   'Glutose': {'end': 24,
#    'Glutose': 6,
#    'IV/IO': 7,
#    'ECG': 6,
#    'Glucagon (Glucagen)': 1},
#   'Dextrose 25%': {'end': 2, 'ECG': 1, 'Ondansetron (Zofran)': 1},
#   'Dextrose 50 % Injectable Solution': {'end': 5},
#   'Vitals/Assess': {'IV/IO': 1},
#   'Dexamethasone (Decadron)': {'end': 2},
#   'Norepinephrine (Levophed)': {'Albuterol (Proventil)': 1, 'end': 1},
#   'Nitroglycerin': {'ECG': 1},
#   'Dextrose 5% in 0.45% NS': {'ECG': 1},
#   'Open/Position Airway': {'IV/IO': 1},
#   'Move Patient': {'ECG': 1}},
#  'Stroke': {'start': {'ECG': 514,
#    'Oxygen': 45,
#    'IV/IO': 264,
#    'Normal saline': 11,
#    'Monitor/Care': 10,
#    'Intubation': 4,
#    'Clear Airway': 4,
#    'Nicardipine (Cardene)': 3,
#    'Midazolam (Versed)': 4,
#    'CPR': 2,
#    'ETCO2 Capnography': 11,
#    'Restraint Applied': 1,
#    'Glucose Check': 4,
#    'Propofol Injection (Diprivan)': 1,
#    'BVM': 1,
#    'Naloxone (Narcan)': 1,
#    'Generic Medication Placeholder': 2,
#    'Dextrose': 3,
#    'Stabilization/Splinting': 3,
#    'Norepinephrine (Levophed)': 1,
#    'Ondansetron (Zofran)': 2,
#    'Diphenhydramine (Benadryl)': 1,
#    'Dextrose 10 % Injectable Solution': 2,
#    'Access Airway': 1,
#    'Aspirin (ASA)': 1,
#    'Cardiac Pacing': 1,
#    'Alteplase (Activase)': 1},
#   'ECG': {'IV/IO': 508,
#    'Oxygen': 34,
#    'ECG': 677,
#    'end': 505,
#    'Naloxone (Narcan)': 8,
#    'Ondansetron (Zofran)': 5,
#    'Normal saline': 24,
#    'Monitor/Care': 2,
#    'Intubation': 8,
#    'ETCO2 Capnography': 9,
#    'Terbutaline Sulfate 1 MG/ML': 1,
#    'Midazolam (Versed)': 5,
#    'Aspirin (ASA)': 6,
#    'Atropine': 2,
#    'Clear Airway': 6,
#    'Defibrillation': 2,
#    'BVM': 1,
#    'Precedex': 1,
#    'Dextrose': 2,
#    'Generic Medication Placeholder': 1,
#    'Nicardipine (Cardene)': 1,
#    'Dextrose 10 % Injectable Solution': 4,
#    'CPAP/BiPAP': 1,
#    'Glucagon (Glucagen)': 1,
#    'Alteplase (Activase)': 1},
#   'IV/IO': {'ECG': 453,
#    'end': 278,
#    'Normal saline': 29,
#    'Ondansetron (Zofran)': 6,
#    'IV/IO': 88,
#    'Monitor/Care': 5,
#    'Naloxone (Narcan)': 17,
#    'Clear Airway': 6,
#    'Midazolam (Versed)': 15,
#    'CPR': 1,
#    'Dextrose 10 % Injectable Solution': 15,
#    'Oxygen': 15,
#    'ETCO2 Capnography': 4,
#    'Dextrose': 4,
#    'CPAP/BiPAP': 1,
#    'Dexamethasone 10mg IV/IM': 1,
#    'Vitals/Assess': 1,
#    'Bleeding Control': 1,
#    'BVM': 1,
#    'Diphenhydramine (Benadryl)': 1,
#    'Aspirin (ASA)': 1,
#    'Intubation': 1,
#    'Glucagon (Glucagen)': 2},
#   'end': {},
#   'Oxygen': {'Intubation': 5,
#    'ECG': 43,
#    'end': 19,
#    'IV/IO': 30,
#    'BVM': 9,
#    'ETCO2 Capnography': 3,
#    'CPAP/BiPAP': 2,
#    'Albuterol (Proventil)': 1,
#    'Normal saline': 1,
#    'Clear Airway': 2,
#    'Oxygen': 2,
#    'Midazolam (Versed)': 1,
#    'Aspirin (ASA)': 1,
#    'Restraint Applied': 1},
#   'Intubation': {'IV/IO': 5,
#    'BVM': 7,
#    'Intubation': 2,
#    'ECG': 6,
#    'Naloxone (Narcan)': 1,
#    'Oxygen': 2,
#    'CPR': 1,
#    'Open/Position Airway': 1,
#    'Midazolam (Versed)': 1,
#    'end': 1},
#   'Naloxone (Narcan)': {'end': 12,
#    'ECG': 10,
#    'Naloxone (Narcan)': 2,
#    'IV/IO': 6,
#    'Oxygen': 1,
#    'ETCO2 Capnography': 2,
#    'Clear Airway': 3},
#   'Ondansetron (Zofran)': {'IV/IO': 1,
#    'end': 9,
#    'ECG': 2,
#    'Monitor/Care': 1,
#    'Normal saline': 1},
#   'Normal saline': {'ECG': 22,
#    'IV/IO': 17,
#    'end': 20,
#    'Dextrose 10 % Injectable Solution': 3,
#    'Norepinephrine (Levophed)': 1,
#    'Dextrose': 1,
#    'Epinephrine 1:10,000': 1,
#    'Oxygen': 2,
#    'Ondansetron (Zofran)': 1,
#    'Naloxone (Narcan)': 1},
#   'Monitor/Care': {'ECG': 15,
#    'end': 1,
#    'IV/IO': 2,
#    'Monitor/Care': 1,
#    'CPAP/BiPAP': 1},
#   'BVM': {'Oxygen': 2,
#    'Intubation': 2,
#    'ECG': 4,
#    'ETCO2 Capnography': 1,
#    'end': 3,
#    'IV/IO': 4,
#    'Midazolam (Versed)': 2,
#    'CPR': 1,
#    'Naloxone (Narcan)': 1},
#   'Clear Airway': {'ECG': 8,
#    'Oxygen': 3,
#    'BVM': 1,
#    'IV/IO': 1,
#    'Midazolam (Versed)': 1,
#    'end': 3,
#    'CPAP/BiPAP': 1,
#    'Clear Airway': 2,
#    'Intubation': 1,
#    'Naloxone (Narcan)': 2},
#   'Dextrose 10 % Injectable Solution': {'end': 15,
#    'Epinephrine 1:10,000': 1,
#    'ECG': 7,
#    'Dextrose': 1,
#    'Glucagon (Glucagen)': 1,
#    'Dextrose 10 % Injectable Solution': 1},
#   'Midazolam (Versed)': {'end': 8,
#    'ECG': 8,
#    'ETCO2 Capnography': 3,
#    'Oxygen': 6,
#    'IV/IO': 3,
#    'Propofol (Diprivan)': 1,
#    'Intubation': 1,
#    'Midazolam (Versed)': 2},
#   'ETCO2 Capnography': {'Naloxone (Narcan)': 2,
#    'CPAP/BiPAP': 2,
#    'ECG': 15,
#    'Glucose Check': 1,
#    'Oxygen': 4,
#    'end': 5,
#    'Intubation': 2,
#    'IV/IO': 4,
#    'ETCO2 Capnography': 4,
#    'Atropine': 1},
#   'Nicardipine (Cardene)': {'Propofol Injection (Diprivan)': 1,
#    'CPAP/BiPAP': 1,
#    'ETCO2 Capnography': 1,
#    'ECG': 2},
#   'Propofol Injection (Diprivan)': {'Fentanyl': 2,
#    'CPAP/BiPAP': 1,
#    'IV/IO': 1},
#   'Fentanyl': {'Normal saline': 1, 'end': 1},
#   'CPAP/BiPAP': {'Propofol Injection (Diprivan)': 1,
#    'Midazolam (Versed)': 1,
#    'ECG': 5,
#    'IV/IO': 1,
#    'end': 2},
#   'Terbutaline Sulfate 1 MG/ML': {'end': 1},
#   'CPR': {'Stabilization/Splinting': 1,
#    'Epinephrine 1:10,000': 1,
#    'Oxygen': 1,
#    'Intubation': 1,
#    'ECG': 1},
#   'Stabilization/Splinting': {'IV/IO': 1, 'ECG': 4},
#   'Epinephrine 1:10,000': {'Dextrose 10 % Injectable Solution': 1,
#    'end': 1,
#    'Epinephrine 1:10,000': 1,
#    'Defibrillation': 1},
#   'Aspirin (ASA)': {'ECG': 4, 'IV/IO': 1, 'end': 4},
#   'Restraint Applied': {'ECG': 1, 'end': 1},
#   'Glucose Check': {'ECG': 2, 'IV/IO': 2, 'Stabilization/Splinting': 1},
#   'Norepinephrine (Levophed)': {'end': 1, 'Propofol Injection (Diprivan)': 1},
#   'Atropine': {'ECG': 1, 'IV/IO': 1, 'ETCO2 Capnography': 1},
#   'Generic Medication Placeholder': {'IV/IO': 1,
#    'ETCO2 Capnography': 1,
#    'Oxygen': 1},
#   'Dextrose': {'Normal saline': 1,
#    'ECG': 4,
#    'IV/IO': 4,
#    'Dextrose': 2,
#    'end': 2},
#   'Defibrillation': {'Normal saline': 1, 'ECG': 1, 'end': 1},
#   'Precedex': {'Oxygen': 1},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 1, 'ECG': 1},
#   'Ipratropium (Atrovent)': {'ECG': 1},
#   'Dexamethasone 10mg IV/IM': {'Albuterol (Proventil)': 1},
#   'Diphenhydramine (Benadryl)': {'Oxygen': 1, 'ECG': 1},
#   'Glucagon (Glucagen)': {'ECG': 1, 'end': 2, 'IV/IO': 1},
#   'Vitals/Assess': {'end': 1},
#   'Bleeding Control': {'end': 1},
#   'Access Airway': {'Monitor/Care': 1},
#   'Propofol (Diprivan)': {'Nicardipine (Cardene)': 1},
#   'Open/Position Airway': {'Naloxone (Narcan)': 1},
#   'Cardiac Pacing': {'ECG': 1},
#   'Alteplase (Activase)': {'ECG': 1, 'end': 1}}}

# %%
#convert weights into percents
for impression, graph in graphs.items():
    #for each inner dictionary, sum up all the values
    #values into percent = current value/sum 

    for node, dictionary in graph.items():
        sum_weights = sum(dictionary.values())
        for node, weight in dictionary.items():
            dictionary[node] = weight/sum_weights
            
graphs
# Out:
# {'Seizures': {'start': {'Clear Airway': 0.006274957216200799,
#    'Stabilization/Splinting': 0.027381631488876214,
#    'IV/IO': 0.2065031374786081,
#    'Midazolam (Versed)': 0.07986309184255562,
#    'ECG': 0.5094124358243012,
#    'Normal saline': 0.011409013120365089,
#    'Ondansetron (Zofran)': 0.0011409013120365088,
#    'Oxygen': 0.0889903023388477,
#    'Restraint Applied': 0.00912721049629207,
#    'ETCO2 Capnography': 0.019965772960638905,
#    'Intubation': 0.006274957216200799,
#    'Dextrose': 0.0034227039361095267,
#    'Wound Care': 0.0011409013120365088,
#    'BVM': 0.0034227039361095267,
#    'Monitor/Care': 0.002852253280091272,
#    'Aspirin (ASA)': 0.0011409013120365088,
#    'Naloxone (Narcan)': 0.003993154592127781,
#    'Glucose Check': 0.002852253280091272,
#    'Dextrose 10 % Injectable Solution': 0.0022818026240730175,
#    'Bleeding Control': 0.0034227039361095267,
#    'Open/Position Airway': 0.0011409013120365088,
#    'CPR': 0.0017113519680547634,
#    'CPAP/BiPAP': 0.0005704506560182544,
#    'Glucagon (Glucagen)': 0.0011409013120365088,
#    'Lorazepam (Ativan)': 0.0005704506560182544,
#    'Generic Medication Placeholder': 0.0005704506560182544,
#    'Haldol': 0.0005704506560182544,
#    'Albuterol (Proventil)': 0.0005704506560182544,
#    'Fentanyl': 0.0011409013120365088,
#    'Cardiac Pacing': 0.0005704506560182544,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.0005704506560182544},
#   'Clear Airway': {'ETCO2 Capnography': 0.07352941176470588,
#    'ECG': 0.27941176470588236,
#    'end': 0.10294117647058823,
#    'Intubation': 0.058823529411764705,
#    'Glucose Check': 0.014705882352941176,
#    'BVM': 0.04411764705882353,
#    'Clear Airway': 0.014705882352941176,
#    'Oxygen': 0.058823529411764705,
#    'IV/IO': 0.11764705882352941,
#    'Midazolam (Versed)': 0.16176470588235295,
#    'Stabilization/Splinting': 0.014705882352941176,
#    'Glucagon (Glucagen)': 0.014705882352941176,
#    'Monitor/Care': 0.014705882352941176,
#    'Epinephrine 1:10,000': 0.014705882352941176,
#    'Defibrillation': 0.014705882352941176},
#   'ETCO2 Capnography': {'ECG': 0.3719512195121951,
#    'IV/IO': 0.23170731707317074,
#    'end': 0.12195121951219512,
#    'Oxygen': 0.04878048780487805,
#    'Glucose Check': 0.024390243902439025,
#    'Clear Airway': 0.018292682926829267,
#    'Normal saline': 0.012195121951219513,
#    'Midazolam (Versed)': 0.06707317073170732,
#    'Intubation': 0.012195121951219513,
#    'CPAP/BiPAP': 0.012195121951219513,
#    'Ipratropium (Atrovent)': 0.006097560975609756,
#    'Access Airway': 0.006097560975609756,
#    'BVM': 0.006097560975609756,
#    'Defibrillation': 0.012195121951219513,
#    'ETCO2 Capnography': 0.042682926829268296,
#    'Ondansetron (Zofran)': 0.006097560975609756},
#   'ECG': {'Midazolam (Versed)': 0.055823569951757405,
#    'end': 0.26085458304617504,
#    'Normal saline': 0.016884906960716747,
#    'IV/IO': 0.2953135768435562,
#    'ETCO2 Capnography': 0.013094417643004824,
#    'Intubation': 0.005513439007580979,
#    'ECG': 0.28738800827015853,
#    'Albuterol (Proventil)': 0.0010337698139214334,
#    'BVM': 0.002067539627842867,
#    'Oxygen': 0.03583735354927636,
#    'Glucose Check': 0.0013783597518952446,
#    'Ondansetron (Zofran)': 0.0027567195037904893,
#    'Clear Airway': 0.004479669193659545,
#    'Wound Care': 0.0006891798759476223,
#    'Aspirin (ASA)': 0.0031013094417643005,
#    'Restraint Applied': 0.003790489317711923,
#    'Dextrose': 0.0006891798759476223,
#    'Patient Cooling/Warming': 0.0006891798759476223,
#    'Stabilization/Splinting': 0.0017229496898690559,
#    'Fentanyl': 0.00034458993797381116,
#    'Dextrose 10 % Injectable Solution': 0.0017229496898690559,
#    'Naloxone (Narcan)': 0.0013783597518952446,
#    'Adenosine (Adenocard)': 0.00034458993797381116,
#    'Monitor/Care': 0.0010337698139214334,
#    'Phenytoin (Dilantin)': 0.00034458993797381116,
#    'Magnesium Sulfate': 0.00034458993797381116,
#    'Glutose': 0.00034458993797381116,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.00034458993797381116,
#    'Nitroglycerin': 0.00034458993797381116,
#    'CPR': 0.00034458993797381116},
#   'Midazolam (Versed)': {'Midazolam (Versed)': 0.0824891461649783,
#    'Oxygen': 0.14327062228654125,
#    'ETCO2 Capnography': 0.03328509406657019,
#    'Intubation': 0.01881331403762663,
#    'ECG': 0.2272069464544139,
#    'Haldol': 0.001447178002894356,
#    'end': 0.29667149059334297,
#    'Clear Airway': 0.008683068017366137,
#    'Normal saline': 0.024602026049204053,
#    'Naloxone (Narcan)': 0.00723589001447178,
#    'IV/IO': 0.12011577424023155,
#    'Restraint Applied': 0.013024602026049204,
#    'Ondansetron (Zofran)': 0.004341534008683068,
#    'BVM': 0.010130246020260492,
#    'Monitor/Care': 0.001447178002894356,
#    'Stabilization/Splinting': 0.002894356005788712,
#    'Patient Cooling/Warming': 0.001447178002894356,
#    'Glucagon (Glucagen)': 0.001447178002894356,
#    'Cardioversion': 0.001447178002894356},
#   'Oxygen': {'end': 0.15592515592515593,
#    'Midazolam (Versed)': 0.10602910602910603,
#    'IV/IO': 0.21621621621621623,
#    'Nebulizer Therapy': 0.004158004158004158,
#    'ETCO2 Capnography': 0.058212058212058215,
#    'ECG': 0.28482328482328484,
#    'Clear Airway': 0.037422037422037424,
#    'BVM': 0.05197505197505198,
#    'Intubation': 0.02494802494802495,
#    'Normal saline': 0.008316008316008316,
#    'Oxygen': 0.012474012474012475,
#    'Patient Cooling/Warming': 0.002079002079002079,
#    'Restraint Applied': 0.012474012474012475,
#    'Naloxone (Narcan)': 0.004158004158004158,
#    'Stabilization/Splinting': 0.010395010395010396,
#    'Glucose Check': 0.002079002079002079,
#    'Monitor/Care': 0.002079002079002079,
#    'Open/Position Airway': 0.002079002079002079,
#    'Ondansetron (Zofran)': 0.002079002079002079,
#    'Epinephrine 1:10,000': 0.002079002079002079},
#   'end': {},
#   'Stabilization/Splinting': {'IV/IO': 0.2073170731707317,
#    'Stabilization/Splinting': 0.10975609756097561,
#    'ECG': 0.4878048780487805,
#    'end': 0.04878048780487805,
#    'Clear Airway': 0.024390243902439025,
#    'ETCO2 Capnography': 0.012195121951219513,
#    'Midazolam (Versed)': 0.036585365853658534,
#    'Bleeding Control': 0.024390243902439025,
#    'Oxygen': 0.012195121951219513,
#    'Restraint Applied': 0.012195121951219513,
#    'Extrication': 0.012195121951219513,
#    'Wound Care': 0.012195121951219513},
#   'IV/IO': {'ECG': 0.36331569664902996,
#    'Normal saline': 0.037037037037037035,
#    'end': 0.2962962962962963,
#    'Midazolam (Versed)': 0.11875367430922987,
#    'Oxygen': 0.031746031746031744,
#    'IV/IO': 0.07348618459729571,
#    'Naloxone (Narcan)': 0.00823045267489712,
#    'Albuterol (Proventil)': 0.0005878894767783657,
#    'ETCO2 Capnography': 0.006466784244562022,
#    'Intubation': 0.003527336860670194,
#    'Clear Airway': 0.003527336860670194,
#    'Ondansetron (Zofran)': 0.01352145796590241,
#    'Dextrose 10 % Injectable Solution': 0.009994121105232217,
#    'Restraint Applied': 0.006466784244562022,
#    'Stabilization/Splinting': 0.005291005291005291,
#    'Epinephrine 1:10,000': 0.003527336860670194,
#    'BVM': 0.0023515579071134627,
#    'Ketorolac (Toradol)': 0.0005878894767783657,
#    'Monitor/Care': 0.0011757789535567313,
#    'Glucagon (Glucagen)': 0.003527336860670194,
#    'Bleeding Control': 0.0011757789535567313,
#    'Vagal Maneuver': 0.0005878894767783657,
#    'Glucose Check': 0.0005878894767783657,
#    'Magnesium Sulfate': 0.0011757789535567313,
#    'Diphenhydramine (Benadryl)': 0.0005878894767783657,
#    'Dexamethasone (Decadron)': 0.0023515579071134627,
#    'CPR': 0.0005878894767783657,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.0011757789535567313,
#    'Aspirin (ASA)': 0.0011757789535567313,
#    'Dextrose': 0.0011757789535567313},
#   'Normal saline': {'ECG': 0.16149068322981366,
#    'end': 0.40993788819875776,
#    'Restraint Applied': 0.018633540372670808,
#    'Oxygen': 0.07453416149068323,
#    'IV/IO': 0.21739130434782608,
#    'Midazolam (Versed)': 0.062111801242236024,
#    'Aspirin (ASA)': 0.006211180124223602,
#    'Intubation': 0.006211180124223602,
#    'Ondansetron (Zofran)': 0.024844720496894408,
#    'Adenosine (Adenocard)': 0.006211180124223602,
#    'Naloxone (Narcan)': 0.006211180124223602,
#    'ETCO2 Capnography': 0.006211180124223602},
#   'Intubation': {'Oxygen': 0.09302325581395349,
#    'ECG': 0.19767441860465115,
#    'BVM': 0.11627906976744186,
#    'end': 0.1511627906976744,
#    'IV/IO': 0.18604651162790697,
#    'ETCO2 Capnography': 0.03488372093023256,
#    'Midazolam (Versed)': 0.10465116279069768,
#    'Normal saline': 0.011627906976744186,
#    'Epinephrine 1:10,000': 0.046511627906976744,
#    'Intubation': 0.023255813953488372,
#    'Clear Airway': 0.03488372093023256},
#   'Restraint Applied': {'ECG': 0.3728813559322034,
#    'IV/IO': 0.11864406779661017,
#    'Midazolam (Versed)': 0.1864406779661017,
#    'end': 0.1694915254237288,
#    'ETCO2 Capnography': 0.05084745762711865,
#    'Oxygen': 0.05084745762711865,
#    'Monitor/Care': 0.01694915254237288,
#    'Intubation': 0.01694915254237288,
#    'Ziprasidone (Geodon)': 0.01694915254237288},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 0.3333333333333333,
#    'Oxygen': 0.16666666666666666,
#    'ETCO2 Capnography': 0.16666666666666666,
#    'end': 0.3333333333333333},
#   'Ipratropium (Atrovent)': {'Oxygen': 1.0},
#   'Ondansetron (Zofran)': {'ECG': 0.14285714285714285,
#    'end': 0.6904761904761905,
#    'Midazolam (Versed)': 0.047619047619047616,
#    'Clear Airway': 0.023809523809523808,
#    'IV/IO': 0.07142857142857142,
#    'ETCO2 Capnography': 0.023809523809523808},
#   'Naloxone (Narcan)': {'ECG': 0.2631578947368421,
#    'Oxygen': 0.15789473684210525,
#    'ETCO2 Capnography': 0.05263157894736842,
#    'end': 0.23684210526315788,
#    'IV/IO': 0.02631578947368421,
#    'Midazolam (Versed)': 0.02631578947368421,
#    'Normal saline': 0.10526315789473684,
#    'Naloxone (Narcan)': 0.05263157894736842,
#    'Haldol': 0.02631578947368421,
#    'Intubation': 0.05263157894736842},
#   'Haldol': {'Intubation': 0.3333333333333333,
#    'Midazolam (Versed)': 0.3333333333333333,
#    'end': 0.3333333333333333},
#   'Nebulizer Therapy': {'ECG': 1.0},
#   'BVM': {'end': 0.109375,
#    'IV/IO': 0.265625,
#    'Midazolam (Versed)': 0.125,
#    'ECG': 0.1875,
#    'Oxygen': 0.09375,
#    'Intubation': 0.140625,
#    'Naloxone (Narcan)': 0.015625,
#    'Defibrillation': 0.015625,
#    'Clear Airway': 0.03125,
#    'Bleeding Control': 0.015625},
#   'Glucose Check': {'end': 0.1875,
#    'BVM': 0.0625,
#    'Midazolam (Versed)': 0.0625,
#    'IV/IO': 0.3125,
#    'ECG': 0.3125,
#    'Stabilization/Splinting': 0.0625},
#   'Dextrose': {'IV/IO': 0.14285714285714285,
#    'ECG': 0.14285714285714285,
#    'Dextrose': 0.21428571428571427,
#    'end': 0.5},
#   'Wound Care': {'Bleeding Control': 0.2,
#    'Stabilization/Splinting': 0.2,
#    'ECG': 0.4,
#    'Patient Cooling/Warming': 0.2},
#   'Bleeding Control': {'Patient Cooling/Warming': 0.08333333333333333,
#    'Stabilization/Splinting': 0.08333333333333333,
#    'ECG': 0.3333333333333333,
#    'end': 0.08333333333333333,
#    'IV/IO': 0.3333333333333333,
#    'ETCO2 Capnography': 0.08333333333333333},
#   'Patient Cooling/Warming': {'end': 0.5,
#    'Clear Airway': 0.16666666666666666,
#    'Restraint Applied': 0.16666666666666666,
#    'IV/IO': 0.16666666666666666},
#   'Monitor/Care': {'ECG': 0.5714285714285714,
#    'CPAP/BiPAP': 0.14285714285714285,
#    'end': 0.07142857142857142,
#    'Vitals/Assess': 0.07142857142857142,
#    'ETCO2 Capnography': 0.07142857142857142,
#    'IV/IO': 0.07142857142857142},
#   'Aspirin (ASA)': {'end': 0.21428571428571427,
#    'ECG': 0.2857142857142857,
#    'IV/IO': 0.35714285714285715,
#    'Midazolam (Versed)': 0.07142857142857142,
#    'Oxygen': 0.07142857142857142},
#   'Dextrose 10 % Injectable Solution': {'end': 0.32142857142857145,
#    'ECG': 0.2857142857142857,
#    'Midazolam (Versed)': 0.03571428571428571,
#    'IV/IO': 0.14285714285714285,
#    'Oxygen': 0.14285714285714285,
#    'Naloxone (Narcan)': 0.03571428571428571,
#    'Dextrose 10 % Injectable Solution': 0.03571428571428571},
#   'CPAP/BiPAP': {'ECG': 0.6, 'end': 0.2, 'Potassium Chloride': 0.2},
#   'Epinephrine 1:10,000': {'Intubation': 0.16666666666666666,
#    'ECG': 0.05555555555555555,
#    'Defibrillation': 0.05555555555555555,
#    'Amiodarone (Cordarone)': 0.05555555555555555,
#    'end': 0.16666666666666666,
#    'Midazolam (Versed)': 0.05555555555555555,
#    'ETCO2 Capnography': 0.16666666666666666,
#    'CPR': 0.05555555555555555,
#    'Gastric Tube Insertion': 0.05555555555555555,
#    'Naloxone (Narcan)': 0.05555555555555555,
#    'Epinephrine 1:10,000': 0.05555555555555555,
#    'Oxygen': 0.05555555555555555},
#   'Open/Position Airway': {'Intubation': 0.3333333333333333,
#    'IV/IO': 0.3333333333333333,
#    'ECG': 0.3333333333333333},
#   'CPR': {'ECG': 0.1111111111111111,
#    'Defibrillation': 0.1111111111111111,
#    'CPR': 0.2222222222222222,
#    'Intubation': 0.1111111111111111,
#    'IV/IO': 0.2222222222222222,
#    'Epinephrine 1:10,000': 0.1111111111111111,
#    'BVM': 0.1111111111111111},
#   'Defibrillation': {'CPR': 0.1111111111111111,
#    'Defibrillation': 0.2222222222222222,
#    'IV/IO': 0.1111111111111111,
#    'Epinephrine 1:10,000': 0.1111111111111111,
#    'end': 0.2222222222222222,
#    'Amiodarone (Cordarone)': 0.2222222222222222},
#   'Amiodarone (Cordarone)': {'Epinephrine 1:10,000': 1.0},
#   'Fentanyl': {'end': 0.3333333333333333,
#    'Normal saline': 0.3333333333333333,
#    'ECG': 0.3333333333333333},
#   'Glucagon (Glucagen)': {'Dextrose 10 % Injectable Solution': 0.1,
#    'Midazolam (Versed)': 0.2,
#    'end': 0.4,
#    'ECG': 0.1,
#    'Dextrose': 0.1,
#    'Oxygen': 0.1},
#   'Adenosine (Adenocard)': {'ECG': 0.5, 'Midazolam (Versed)': 0.5},
#   'Ketorolac (Toradol)': {'Midazolam (Versed)': 1.0},
#   'Lorazepam (Ativan)': {'ECG': 1.0},
#   'Phenytoin (Dilantin)': {'Restraint Applied': 1.0},
#   'Generic Medication Placeholder': {'Midazolam (Versed)': 1.0},
#   'Extrication': {'ECG': 1.0},
#   'Vitals/Assess': {'end': 1.0},
#   'Access Airway': {'end': 1.0},
#   'Potassium Chloride': {'end': 1.0},
#   'Vagal Maneuver': {'ECG': 1.0},
#   'Cardioversion': {'Defibrillation': 1.0},
#   'Magnesium Sulfate': {'end': 0.3333333333333333,
#    'Midazolam (Versed)': 0.6666666666666666},
#   'Diphenhydramine (Benadryl)': {'Midazolam (Versed)': 1.0},
#   'Dexamethasone (Decadron)': {'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.2,
#    'ECG': 0.2,
#    'Albuterol (Proventil)': 0.2,
#    'end': 0.4},
#   'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': {'Oxygen': 0.6,
#    'IV/IO': 0.2,
#    'Dexamethasone (Decadron)': 0.2},
#   'Cardiac Pacing': {'Intubation': 1.0},
#   'Gastric Tube Insertion': {'Clear Airway': 1.0},
#   'Glutose': {'IV/IO': 1.0},
#   'Nitroglycerin': {'ECG': 1.0},
#   'Ziprasidone (Geodon)': {'ECG': 1.0}},
#  'Chest Pain (Angina Cardiac)': {'start': {'ECG': 0.6847612818835841,
#    'IV/IO': 0.05733594942228036,
#    'Aspirin (ASA)': 0.170917811205581,
#    'Oxygen': 0.048615652932199695,
#    'Monitor/Care': 0.006104207543056464,
#    'Vagal Maneuver': 0.0004360148245040331,
#    'ETCO2 Capnography': 0.0028340963592762155,
#    'Albuterol (Proventil)': 0.0054501853063004145,
#    'Ondansetron (Zofran)': 0.0021800741225201656,
#    'Normal saline': 0.006540222367560497,
#    'Generic Medication Placeholder': 0.0004360148245040331,
#    'Glucose Check': 0.0010900370612600828,
#    'Nitroglycerin': 0.005232177894048398,
#    'Adenosine (Adenocard)': 0.0006540222367560497,
#    'Dextrose': 0.0006540222367560497,
#    'Midazolam (Versed)': 0.0004360148245040331,
#    'Stabilization/Splinting': 0.0008720296490080662,
#    'Bleeding Control': 0.0004360148245040331,
#    'Ketamine (Ketalar)': 0.00021800741225201656,
#    'Patient Cooling/Warming': 0.00021800741225201656,
#    'Ipratropium (Atrovent)': 0.0004360148245040331,
#    'Vitals/Assess': 0.00021800741225201656,
#    'Nebulizer Therapy': 0.00021800741225201656,
#    'Nitroprusside (Nitropress)': 0.0004360148245040331,
#    'Fentanyl': 0.00021800741225201656,
#    'CPR': 0.0006540222367560497,
#    'Amiodarone (Cordarone)': 0.00021800741225201656,
#    'Irrigation': 0.00021800741225201656,
#    'Labetalol (Normodyne)': 0.00021800741225201656,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.0008720296490080662,
#    'Move Patient': 0.0006540222367560497,
#    'Insulin': 0.00021800741225201656},
#   'ECG': {'ECG': 0.4461286710877616,
#    'Aspirin (ASA)': 0.14012574283007492,
#    'IV/IO': 0.14727413659460856,
#    'end': 0.22650934458702954,
#    'Normal saline': 0.005339764016880544,
#    'Oxygen': 0.012229782103178021,
#    'Monitor/Care': 0.0012918783911807768,
#    'Albuterol (Proventil)': 0.0035311342692274567,
#    'Stabilization/Splinting': 8.612522607871846e-05,
#    'Vagal Maneuver': 0.0008612522607871846,
#    'Defibrillation': 0.0005167513564723107,
#    'CPAP/BiPAP': 0.0004306261303935923,
#    'Dexamethasone 10mg IV/IM': 0.0008612522607871846,
#    'Glucose Check': 0.0003445009043148738,
#    'Ondansetron (Zofran)': 0.0025837567823615536,
#    'Diphenhydramine (Benadryl)': 8.612522607871846e-05,
#    'Adenosine (Adenocard)': 0.0012057531651020585,
#    'Cardioversion': 8.612522607871846e-05,
#    'Nitroglycerin': 0.0035311342692274567,
#    'Fentanyl': 0.0012918783911807768,
#    'Terbutaline Sulfate 1 MG/ML': 0.00025837567823615537,
#    'Midazolam (Versed)': 0.00025837567823615537,
#    'ETCO2 Capnography': 0.0016363792954956506,
#    'Dextrose': 0.0004306261303935923,
#    'Ketorolac (Toradol)': 8.612522607871846e-05,
#    'Ipratropium (Atrovent)': 8.612522607871846e-05,
#    'Epinephrine 1:10,000': 8.612522607871846e-05,
#    'CPR': 8.612522607871846e-05,
#    'Clear Airway': 0.0004306261303935923,
#    'Nebulizer Therapy': 8.612522607871846e-05,
#    'Magnesium Sulfate': 8.612522607871846e-05,
#    'Dexamethasone (Decadron)': 0.0005167513564723107,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.0012057531651020585,
#    'Bleeding Control': 8.612522607871846e-05,
#    'Amiodarone (Cordarone)': 8.612522607871846e-05,
#    'Intubation': 8.612522607871846e-05,
#    'Heparin': 0.0001722504521574369},
#   'Aspirin (ASA)': {'end': 0.2341838518000699,
#    'ECG': 0.44774554351625306,
#    'IV/IO': 0.23243621111499477,
#    'Normal saline': 0.0129325410695561,
#    'Oxygen': 0.03320517301642782,
#    'Aspirin (ASA)': 0.0017476406850751485,
#    'ETCO2 Capnography': 0.0013981125480601187,
#    'Nitroglycerin': 0.014330653617616217,
#    'Ondansetron (Zofran)': 0.004194337644180357,
#    'Monitor/Care': 0.003844809507165327,
#    'Glucose Check': 0.0003495281370150297,
#    'Adenosine (Adenocard)': 0.0003495281370150297,
#    'Terbutaline Sulfate 1 MG/ML': 0.0006990562740300594,
#    'Dexamethasone 10mg IV/IM': 0.0006990562740300594,
#    'Albuterol (Proventil)': 0.002446696959105208,
#    'Ipratropium (Atrovent)': 0.0020971688220901784,
#    'Dextrose': 0.0006990562740300594,
#    'Naloxone (Narcan)': 0.0003495281370150297,
#    'Restraint Applied': 0.0006990562740300594,
#    'Midazolam (Versed)': 0.0003495281370150297,
#    'Glutose': 0.0006990562740300594,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.002446696959105208,
#    'Fentanyl': 0.0006990562740300594,
#    'Diphenhydramine (Benadryl)': 0.0003495281370150297,
#    'Dexamethasone (Decadron)': 0.0003495281370150297,
#    'Clear Airway': 0.0003495281370150297,
#    'Heparin': 0.0003495281370150297},
#   'end': {},
#   'IV/IO': {'ECG': 0.437248322147651,
#    'Aspirin (ASA)': 0.11845637583892618,
#    'end': 0.2973154362416107,
#    'Normal saline': 0.025503355704697986,
#    'ETCO2 Capnography': 0.0010067114093959733,
#    'IV/IO': 0.036241610738255034,
#    'Nitroglycerin': 0.014093959731543624,
#    'Oxygen': 0.015771812080536914,
#    'Ondansetron (Zofran)': 0.019798657718120807,
#    'Adenosine (Adenocard)': 0.004026845637583893,
#    'Albuterol (Proventil)': 0.0050335570469798654,
#    'BVM': 0.0003355704697986577,
#    'Vagal Maneuver': 0.0013422818791946308,
#    'Fentanyl': 0.0050335570469798654,
#    'Dexamethasone 10mg IV/IM': 0.002348993288590604,
#    'Terbutaline Sulfate 1 MG/ML': 0.0003355704697986577,
#    'Monitor/Care': 0.0026845637583892616,
#    'Naloxone (Narcan)': 0.0006711409395973154,
#    'Intubation': 0.0006711409395973154,
#    'Stabilization/Splinting': 0.0003355704697986577,
#    'Defibrillation': 0.0006711409395973154,
#    'Dextrose': 0.0010067114093959733,
#    'Midazolam (Versed)': 0.0016778523489932886,
#    'Glucose Check': 0.0003355704697986577,
#    'Nebulizer Therapy': 0.0003355704697986577,
#    'Epinephrine 1:10,000': 0.0010067114093959733,
#    'CPAP/BiPAP': 0.0006711409395973154,
#    'Norepinephrine (Levophed)': 0.0003355704697986577,
#    'Dextrose 10 % Injectable Solution': 0.0006711409395973154,
#    'Dexamethasone (Decadron)': 0.0030201342281879194,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.0010067114093959733,
#    'Magnesium Sulfate': 0.0003355704697986577,
#    'Furosemide (Lasix)': 0.0003355704697986577,
#    'Sodium Bicarbonate': 0.0003355704697986577},
#   'Normal saline': {'ECG': 0.1981981981981982,
#    'Oxygen': 0.036036036036036036,
#    'end': 0.2927927927927928,
#    'IV/IO': 0.32882882882882886,
#    'Adenosine (Adenocard)': 0.009009009009009009,
#    'Fentanyl': 0.009009009009009009,
#    'Aspirin (ASA)': 0.04504504504504504,
#    'Nitroglycerin': 0.013513513513513514,
#    'Ondansetron (Zofran)': 0.03153153153153153,
#    'Monitor/Care': 0.009009009009009009,
#    'Albuterol (Proventil)': 0.0045045045045045045,
#    'Midazolam (Versed)': 0.009009009009009009,
#    'Vagal Maneuver': 0.0045045045045045045,
#    'Epinephrine 1:10,000': 0.0045045045045045045,
#    'Diphenhydramine (Benadryl)': 0.0045045045045045045},
#   'ETCO2 Capnography': {'ECG': 0.4225352112676056,
#    'IV/IO': 0.18309859154929578,
#    'Oxygen': 0.056338028169014086,
#    'Aspirin (ASA)': 0.04225352112676056,
#    'ETCO2 Capnography': 0.11267605633802817,
#    'CPR': 0.014084507042253521,
#    'Epinephrine 1:10,000': 0.014084507042253521,
#    'Intubation': 0.014084507042253521,
#    'Albuterol (Proventil)': 0.028169014084507043,
#    'end': 0.11267605633802817},
#   'Oxygen': {'ECG': 0.5023847376788553,
#    'Aspirin (ASA)': 0.07631160572337042,
#    'Nebulizer Therapy': 0.034976152623211444,
#    'IV/IO': 0.13354531001589826,
#    'end': 0.1383147853736089,
#    'Intubation': 0.006359300476947536,
#    'Oxygen': 0.017488076311605722,
#    'ETCO2 Capnography': 0.03179650238473768,
#    'CPR': 0.0047694753577106515,
#    'Fentanyl': 0.0047694753577106515,
#    'CPAP/BiPAP': 0.014308426073131956,
#    'BVM': 0.001589825119236884,
#    'Albuterol (Proventil)': 0.00794912559618442,
#    'Normal saline': 0.003179650238473768,
#    'Nitroglycerin': 0.009538950715421303,
#    'Dexamethasone 10MG PO': 0.003179650238473768,
#    'Ondansetron (Zofran)': 0.003179650238473768,
#    'Cardioversion': 0.003179650238473768,
#    'Naloxone (Narcan)': 0.001589825119236884,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.001589825119236884},
#   'Monitor/Care': {'end': 0.10606060606060606,
#    'ECG': 0.8333333333333334,
#    'Monitor/Care': 0.015151515151515152,
#    'IV/IO': 0.045454545454545456},
#   'Nitroglycerin': {'Nitroglycerin': 0.10052910052910052,
#    'end': 0.2804232804232804,
#    'IV/IO': 0.07407407407407407,
#    'Ondansetron (Zofran)': 0.037037037037037035,
#    'ECG': 0.3544973544973545,
#    'Normal saline': 0.010582010582010581,
#    'Oxygen': 0.0582010582010582,
#    'Aspirin (ASA)': 0.031746031746031744,
#    'Fentanyl': 0.031746031746031744,
#    'Furosemide (Lasix)': 0.010582010582010581,
#    'Dextrose': 0.005291005291005291,
#    'Dexamethasone (Decadron)': 0.005291005291005291},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 0.79,
#    'Dexamethasone 10mg IV/IM': 0.03,
#    'Aspirin (ASA)': 0.08,
#    'Oxygen': 0.01,
#    'end': 0.06,
#    'IV/IO': 0.01,
#    'Dexamethasone 10MG PO': 0.01,
#    'Dexamethasone (Decadron)': 0.01},
#   'Ipratropium (Atrovent)': {'Oxygen': 0.6304347826086957,
#    'ECG': 0.16304347826086957,
#    'IV/IO': 0.06521739130434782,
#    'Dexamethasone 10mg IV/IM': 0.010869565217391304,
#    'end': 0.06521739130434782,
#    'Aspirin (ASA)': 0.043478260869565216,
#    'Nitroglycerin': 0.010869565217391304,
#    'CPAP/BiPAP': 0.010869565217391304},
#   'Nebulizer Therapy': {'ECG': 0.68,
#    'Dexamethasone 10mg IV/IM': 0.08,
#    'IV/IO': 0.08,
#    'end': 0.12,
#    'Aspirin (ASA)': 0.04},
#   'Ondansetron (Zofran)': {'end': 0.5,
#    'IV/IO': 0.03731343283582089,
#    'Oxygen': 0.022388059701492536,
#    'ECG': 0.26119402985074625,
#    'Normal saline': 0.05223880597014925,
#    'Aspirin (ASA)': 0.05223880597014925,
#    'Adenosine (Adenocard)': 0.007462686567164179,
#    'Nitroglycerin': 0.03731343283582089,
#    'Morphine': 0.007462686567164179,
#    'Fentanyl': 0.014925373134328358,
#    'Ondansetron (Zofran)': 0.007462686567164179},
#   'Stabilization/Splinting': {'end': 0.3333333333333333,
#    'ECG': 0.6666666666666666},
#   'Vagal Maneuver': {'ECG': 0.4117647058823529,
#    'IV/IO': 0.35294117647058826,
#    'Adenosine (Adenocard)': 0.11764705882352941,
#    'Normal saline': 0.11764705882352941},
#   'Adenosine (Adenocard)': {'ECG': 0.4888888888888889,
#    'Diphenhydramine (Benadryl)': 0.022222222222222223,
#    'Adenosine (Adenocard)': 0.2222222222222222,
#    'end': 0.13333333333333333,
#    'IV/IO': 0.022222222222222223,
#    'Oxygen': 0.044444444444444446,
#    'Normal saline': 0.022222222222222223,
#    'Cardioversion': 0.022222222222222223,
#    'Midazolam (Versed)': 0.022222222222222223},
#   'Defibrillation': {'ECG': 0.4,
#    'Defibrillation': 0.25,
#    'end': 0.15,
#    'CPR': 0.05,
#    'IV/IO': 0.05,
#    'Normal saline': 0.05,
#    'Amiodarone (Cordarone)': 0.05},
#   'CPAP/BiPAP': {'Nitroglycerin': 0.1111111111111111,
#    'ECG': 0.3333333333333333,
#    'Magnesium Sulfate': 0.05555555555555555,
#    'IV/IO': 0.16666666666666666,
#    'Albuterol (Proventil)': 0.05555555555555555,
#    'end': 0.05555555555555555,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.1111111111111111,
#    'Oxygen': 0.05555555555555555,
#    'Dexamethasone (Decadron)': 0.05555555555555555},
#   'Dexamethasone 10mg IV/IM': {'end': 0.5769230769230769,
#    'Ipratropium (Atrovent)': 0.15384615384615385,
#    'ECG': 0.11538461538461539,
#    'Terbutaline Sulfate 1 MG/ML': 0.038461538461538464,
#    'CPAP/BiPAP': 0.038461538461538464,
#    'Magnesium Sulfate': 0.038461538461538464,
#    'Albuterol (Proventil)': 0.038461538461538464},
#   'Intubation': {'CPR': 0.07692307692307693,
#    'BVM': 0.38461538461538464,
#    'Epinephrine 1:10,000': 0.23076923076923078,
#    'Defibrillation': 0.07692307692307693,
#    'IV/IO': 0.23076923076923078},
#   'CPR': {'IV/IO': 0.25,
#    'BVM': 0.08333333333333333,
#    'Oxygen': 0.16666666666666666,
#    'Defibrillation': 0.08333333333333333,
#    'Intubation': 0.08333333333333333,
#    'Epinephrine 1:10,000': 0.08333333333333333,
#    'ECG': 0.16666666666666666,
#    'end': 0.08333333333333333},
#   'BVM': {'end': 0.125,
#    'Naloxone (Narcan)': 0.125,
#    'IV/IO': 0.125,
#    'Intubation': 0.125,
#    'ETCO2 Capnography': 0.25,
#    'Epinephrine 1:10,000': 0.125,
#    'Oxygen': 0.125},
#   'Glucose Check': {'ECG': 0.6363636363636364,
#    'end': 0.2727272727272727,
#    'IV/IO': 0.09090909090909091},
#   'Diphenhydramine (Benadryl)': {'ECG': 0.25,
#    'Epinephrine 1:1,000': 0.25,
#    'end': 0.5},
#   'Epinephrine 1:1,000': {'end': 1.0},
#   'Cardioversion': {'Defibrillation': 0.25, 'ECG': 0.5, 'end': 0.25},
#   'Fentanyl': {'Ondansetron (Zofran)': 0.125,
#    'Normal saline': 0.020833333333333332,
#    'end': 0.4375,
#    'ECG': 0.1875,
#    'Fentanyl': 0.041666666666666664,
#    'Oxygen': 0.08333333333333333,
#    'Monitor/Care': 0.020833333333333332,
#    'IV/IO': 0.020833333333333332,
#    'Nitroglycerin': 0.041666666666666664,
#    'Midazolam (Versed)': 0.020833333333333332},
#   'Terbutaline Sulfate 1 MG/ML': {'Oxygen': 0.14285714285714285,
#    'end': 0.2857142857142857,
#    'IV/IO': 0.2857142857142857,
#    'Dexamethasone 10mg IV/IM': 0.14285714285714285,
#    'ECG': 0.14285714285714285},
#   'Naloxone (Narcan)': {'ECG': 0.125,
#    'end': 0.5,
#    'Epinephrine 1:10,000': 0.125,
#    'Gastric Tube Insertion': 0.125,
#    'Naloxone (Narcan)': 0.125},
#   'Midazolam (Versed)': {'Oxygen': 0.25,
#    'ECG': 0.1875,
#    'end': 0.25,
#    'Normal saline': 0.0625,
#    'Defibrillation': 0.0625,
#    'IV/IO': 0.125,
#    'Haldol': 0.0625},
#   'Generic Medication Placeholder': {'ECG': 0.5, 'Nitroglycerin': 0.5},
#   'Dextrose': {'ECG': 0.375,
#    'end': 0.4375,
#    'Dextrose': 0.125,
#    'IV/IO': 0.0625},
#   'Epinephrine 1:10,000': {'Naloxone (Narcan)': 0.1111111111111111,
#    'end': 0.2222222222222222,
#    'Defibrillation': 0.16666666666666666,
#    'Intubation': 0.05555555555555555,
#    'Epinephrine 1:10,000': 0.16666666666666666,
#    'Clear Airway': 0.1111111111111111,
#    'CPR': 0.05555555555555555,
#    'Sodium Bicarbonate': 0.05555555555555555,
#    'ROSC': 0.05555555555555555},
#   'Gastric Tube Insertion': {'Epinephrine 1:10,000': 1.0},
#   'Bleeding Control': {'ECG': 1.0},
#   'Ketamine (Ketalar)': {'ECG': 1.0},
#   'Morphine': {'ECG': 1.0},
#   'Restraint Applied': {'ECG': 0.5, 'end': 0.5},
#   'Amiodarone (Cordarone)': {'Epinephrine 1:10,000': 0.3333333333333333,
#    'Midazolam (Versed)': 0.3333333333333333,
#    'end': 0.3333333333333333},
#   'Patient Cooling/Warming': {'ECG': 1.0},
#   'Ketorolac (Toradol)': {'Aspirin (ASA)': 1.0},
#   'Magnesium Sulfate': {'end': 0.4,
#    'ECG': 0.2,
#    'IV/IO': 0.2,
#    'Albuterol (Proventil)': 0.2},
#   'Vitals/Assess': {'ECG': 1.0},
#   'Nitroprusside (Nitropress)': {'ECG': 1.0},
#   'Clear Airway': {'Epinephrine 1:10,000': 0.1,
#    'Oxygen': 0.2,
#    'Clear Airway': 0.1,
#    'ECG': 0.3,
#    'Intubation': 0.2,
#    'end': 0.1},
#   'Dexamethasone 10MG PO': {'end': 0.3333333333333333,
#    'ECG': 0.6666666666666666},
#   'Irrigation': {'ECG': 1.0},
#   'Sodium Bicarbonate': {'Clear Airway': 0.5, 'ECG': 0.5},
#   'Haldol': {'Oxygen': 1.0},
#   'Labetalol (Normodyne)': {'Aspirin (ASA)': 1.0},
#   'Norepinephrine (Levophed)': {'end': 1.0},
#   'Dextrose 10 % Injectable Solution': {'end': 0.5, 'ECG': 0.5},
#   'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': {'ECG': 0.53125,
#    'IV/IO': 0.1875,
#    'end': 0.03125,
#    'Oxygen': 0.1875,
#    'Aspirin (ASA)': 0.03125,
#    'Dexamethasone (Decadron)': 0.03125},
#   'Dexamethasone (Decadron)': {'end': 0.5,
#    'Aspirin (ASA)': 0.05,
#    'Magnesium Sulfate': 0.05,
#    'ECG': 0.15,
#    'ETCO2 Capnography': 0.1,
#    'Oxygen': 0.05,
#    'Albuterol (Proventil)': 0.05,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.05},
#   'Glutose': {'IV/IO': 0.5, 'ECG': 0.5},
#   'Furosemide (Lasix)': {'ECG': 0.3333333333333333,
#    'Nitroglycerin': 0.3333333333333333,
#    'end': 0.3333333333333333},
#   'Move Patient': {'ECG': 1.0},
#   'Insulin': {'Aspirin (ASA)': 1.0},
#   'ROSC': {'CPR': 1.0},
#   'Heparin': {'Nitroglycerin': 0.3333333333333333,
#    'end': 0.3333333333333333,
#    'Oxygen': 0.3333333333333333}},
#  'Chest Pain (STEMI MI)': {'start': {'ETCO2 Capnography': 0.004024144869215292,
#    'ECG': 0.6197183098591549,
#    'IV/IO': 0.07645875251509054,
#    'Aspirin (ASA)': 0.1448692152917505,
#    'Oxygen': 0.07645875251509054,
#    'Monitor/Care': 0.012072434607645875,
#    'Normal saline': 0.018108651911468814,
#    'Stabilization/Splinting': 0.002012072434607646,
#    'Restraint Applied': 0.004024144869215292,
#    'BVM': 0.002012072434607646,
#    'Ketamine (Ketalar)': 0.002012072434607646,
#    'CPR': 0.004024144869215292,
#    'Nitroglycerin': 0.01609657947686117,
#    'Vitals/Assess': 0.002012072434607646,
#    'Fentanyl': 0.002012072434607646,
#    'Naloxone (Narcan)': 0.002012072434607646,
#    'Generic Medication Placeholder': 0.002012072434607646,
#    'Clear Airway': 0.002012072434607646,
#    'Albuterol (Proventil)': 0.002012072434607646,
#    'Move Patient': 0.002012072434607646,
#    'Intubation': 0.002012072434607646,
#    'Heparin': 0.002012072434607646},
#   'ETCO2 Capnography': {'IV/IO': 0.6,
#    'Intubation': 0.06666666666666667,
#    'Aspirin (ASA)': 0.06666666666666667,
#    'ECG': 0.06666666666666667,
#    'CPAP/BiPAP': 0.06666666666666667,
#    'ETCO2 Capnography': 0.06666666666666667,
#    'end': 0.06666666666666667},
#   'IV/IO': {'ECG': 0.545662100456621,
#    'Nitroglycerin': 0.03424657534246575,
#    'end': 0.1552511415525114,
#    'Aspirin (ASA)': 0.0639269406392694,
#    'Oxygen': 0.0182648401826484,
#    'IV/IO': 0.06164383561643835,
#    'Normal saline': 0.03881278538812785,
#    'Fentanyl': 0.01598173515981735,
#    'Naloxone (Narcan)': 0.00228310502283105,
#    'Epinephrine 1:10,000': 0.01141552511415525,
#    'Ondansetron (Zofran)': 0.01598173515981735,
#    'CPR': 0.0045662100456621,
#    'Midazolam (Versed)': 0.00228310502283105,
#    'Defibrillation': 0.0045662100456621,
#    'Monitor/Care': 0.0045662100456621,
#    'Dextrose': 0.00228310502283105,
#    'CPAP/BiPAP': 0.00228310502283105,
#    'BVM': 0.00228310502283105,
#    'Dexamethasone (Decadron)': 0.00228310502283105,
#    'Adenosine (Adenocard)': 0.00228310502283105,
#    'Amiodarone (Cordarone)': 0.00228310502283105,
#    'Dextrose 10 % Injectable Solution': 0.00228310502283105,
#    'Albuterol (Proventil)': 0.00228310502283105,
#    'Epinephrine 1:1,000': 0.00228310502283105},
#   'ECG': {'ECG': 0.45866141732283466,
#    'end': 0.20275590551181102,
#    'IV/IO': 0.14435695538057744,
#    'Aspirin (ASA)': 0.11811023622047244,
#    'Normal saline': 0.013123359580052493,
#    'Oxygen': 0.017716535433070866,
#    'Glucose Check': 0.0006561679790026247,
#    'Ondansetron (Zofran)': 0.0026246719160104987,
#    'Nitroglycerin': 0.011811023622047244,
#    'Monitor/Care': 0.0013123359580052493,
#    'ETCO2 Capnography': 0.0032808398950131233,
#    'Dextrose': 0.0006561679790026247,
#    'CPR': 0.005249343832020997,
#    'BVM': 0.0013123359580052493,
#    'Atropine': 0.0006561679790026247,
#    'Albuterol (Proventil)': 0.001968503937007874,
#    'Naloxone (Narcan)': 0.0026246719160104987,
#    'Generic Medication Placeholder': 0.0006561679790026247,
#    'Vagal Maneuver': 0.0006561679790026247,
#    'Ipratropium (Atrovent)': 0.0006561679790026247,
#    'Epinephrine 1:10,000': 0.0013123359580052493,
#    'Midazolam (Versed)': 0.0013123359580052493,
#    'Intubation': 0.0006561679790026247,
#    'CPAP/BiPAP': 0.0013123359580052493,
#    'Dopamine': 0.0006561679790026247,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.0006561679790026247,
#    'Furosemide (Lasix)': 0.0006561679790026247,
#    'Fentanyl': 0.0026246719160104987,
#    'Glucagon (Glucagen)': 0.0006561679790026247,
#    'Heparin': 0.0013123359580052493},
#   'end': {},
#   'Nitroglycerin': {'Nitroglycerin': 0.06060606060606061,
#    'end': 0.22727272727272727,
#    'ECG': 0.3939393939393939,
#    'IV/IO': 0.10606060606060606,
#    'Fentanyl': 0.06060606060606061,
#    'Oxygen': 0.15151515151515152},
#   'Aspirin (ASA)': {'end': 0.1896551724137931,
#    'Normal saline': 0.03103448275862069,
#    'ECG': 0.40344827586206894,
#    'IV/IO': 0.2620689655172414,
#    'Oxygen': 0.03793103448275862,
#    'Nitroglycerin': 0.041379310344827586,
#    'Generic Medication Placeholder': 0.0034482758620689655,
#    'Monitor/Care': 0.006896551724137931,
#    'ETCO2 Capnography': 0.010344827586206896,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.0034482758620689655,
#    'Heparin': 0.006896551724137931,
#    'Enoxaparin': 0.0034482758620689655},
#   'Normal saline': {'end': 0.22580645161290322,
#    'ECG': 0.25806451612903225,
#    'IV/IO': 0.3709677419354839,
#    'Oxygen': 0.03225806451612903,
#    'Aspirin (ASA)': 0.06451612903225806,
#    'Ondansetron (Zofran)': 0.016129032258064516,
#    'ETCO2 Capnography': 0.016129032258064516,
#    'Nitroglycerin': 0.016129032258064516},
#   'Oxygen': {'ECG': 0.4909090909090909,
#    'end': 0.045454545454545456,
#    'CPAP/BiPAP': 0.01818181818181818,
#    'Albuterol (Proventil)': 0.00909090909090909,
#    'IV/IO': 0.16363636363636364,
#    'CPR': 0.00909090909090909,
#    'Normal saline': 0.02727272727272727,
#    'BVM': 0.07272727272727272,
#    'Nebulizer Therapy': 0.01818181818181818,
#    'Fentanyl': 0.02727272727272727,
#    'Aspirin (ASA)': 0.02727272727272727,
#    'ETCO2 Capnography': 0.01818181818181818,
#    'Clear Airway': 0.00909090909090909,
#    'Oxygen': 0.00909090909090909,
#    'Nitroglycerin': 0.01818181818181818,
#    'Intubation': 0.00909090909090909,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.00909090909090909,
#    'Ondansetron (Zofran)': 0.00909090909090909,
#    'Epinephrine 1:10,000': 0.00909090909090909},
#   'Monitor/Care': {'ECG': 0.7692307692307693,
#    'IV/IO': 0.07692307692307693,
#    'Normal saline': 0.07692307692307693,
#    'Vitals/Assess': 0.07692307692307693},
#   'Glucose Check': {'ECG': 1.0},
#   'Ondansetron (Zofran)': {'end': 0.5,
#    'ECG': 0.3333333333333333,
#    'Nitroglycerin': 0.05555555555555555,
#    'Oxygen': 0.05555555555555555,
#    'Normal saline': 0.05555555555555555},
#   'CPAP/BiPAP': {'ECG': 0.7142857142857143,
#    'IV/IO': 0.14285714285714285,
#    'Nitroglycerin': 0.14285714285714285},
#   'Fentanyl': {'end': 0.3,
#    'ECG': 0.15,
#    'Monitor/Care': 0.05,
#    'Normal saline': 0.05,
#    'Ondansetron (Zofran)': 0.15,
#    'Oxygen': 0.05,
#    'Nitroglycerin': 0.15,
#    'IV/IO': 0.05,
#    'Fentanyl': 0.05},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 0.6666666666666666,
#    'ECG': 0.16666666666666666,
#    'Oxygen': 0.16666666666666666},
#   'Ipratropium (Atrovent)': {'ECG': 0.2,
#    'Oxygen': 0.4,
#    'IV/IO': 0.2,
#    'Aspirin (ASA)': 0.2},
#   'Stabilization/Splinting': {'ECG': 1.0},
#   'Naloxone (Narcan)': {'Cardiac Pacing': 0.125,
#    'Naloxone (Narcan)': 0.25,
#    'IV/IO': 0.125,
#    'ECG': 0.25,
#    'Intubation': 0.125,
#    'end': 0.125},
#   'Cardiac Pacing': {'end': 1.0},
#   'Dextrose': {'ECG': 0.5, 'end': 0.5},
#   'CPR': {'ECG': 0.2777777777777778,
#    'IV/IO': 0.2222222222222222,
#    'end': 0.05555555555555555,
#    'Oxygen': 0.16666666666666666,
#    'Defibrillation': 0.1111111111111111,
#    'Epinephrine 1:10,000': 0.1111111111111111,
#    'Intubation': 0.05555555555555555},
#   'BVM': {'CPR': 0.17647058823529413,
#    'end': 0.058823529411764705,
#    'ECG': 0.29411764705882354,
#    'IV/IO': 0.17647058823529413,
#    'Defibrillation': 0.11764705882352941,
#    'Intubation': 0.058823529411764705,
#    'Epinephrine 1:10,000': 0.058823529411764705,
#    'Normal saline': 0.058823529411764705},
#   'Epinephrine 1:10,000': {'Epinephrine 1:10,000': 0.3,
#    'ETCO2 Capnography': 0.05,
#    'Defibrillation': 0.1,
#    'Clear Airway': 0.05,
#    'end': 0.15,
#    'Intubation': 0.1,
#    'ROSC': 0.15,
#    'ECG': 0.05,
#    'Oxygen': 0.05},
#   'Intubation': {'Intubation': 0.06666666666666667,
#    'BVM': 0.3333333333333333,
#    'IV/IO': 0.2,
#    'Epinephrine 1:10,000': 0.2,
#    'ECG': 0.13333333333333333,
#    'Atropine': 0.06666666666666667},
#   'Atropine': {'ECG': 0.3333333333333333,
#    'Epinephrine 1:1,000': 0.3333333333333333,
#    'end': 0.3333333333333333},
#   'Nebulizer Therapy': {'ECG': 0.5, 'Aspirin (ASA)': 0.5},
#   'Restraint Applied': {'Oxygen': 0.5, 'ECG': 0.5},
#   'Generic Medication Placeholder': {'Ondansetron (Zofran)': 0.3333333333333333,
#    'end': 0.3333333333333333,
#    'ECG': 0.3333333333333333},
#   'Ketamine (Ketalar)': {'ECG': 1.0},
#   'Defibrillation': {'CPR': 0.1111111111111111,
#    'IV/IO': 0.2222222222222222,
#    'Intubation': 0.2222222222222222,
#    'ECG': 0.3333333333333333,
#    'Defibrillation': 0.1111111111111111},
#   'Clear Airway': {'Intubation': 0.5, 'ECG': 0.25, 'CPR': 0.25},
#   'Vagal Maneuver': {'ECG': 1.0},
#   'Midazolam (Versed)': {'ECG': 0.3333333333333333,
#    'IV/IO': 0.6666666666666666},
#   'Vitals/Assess': {'ECG': 1.0},
#   'Dopamine': {'ECG': 1.0},
#   'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': {'end': 0.3333333333333333,
#    'ECG': 0.3333333333333333,
#    'CPAP/BiPAP': 0.3333333333333333},
#   'Furosemide (Lasix)': {'end': 1.0},
#   'Dexamethasone (Decadron)': {'Magnesium Sulfate': 1.0},
#   'Magnesium Sulfate': {'ECG': 1.0},
#   'ROSC': {'Gastric Tube Insertion': 0.3333333333333333,
#    'end': 0.3333333333333333,
#    'ECG': 0.3333333333333333},
#   'Gastric Tube Insertion': {'Clear Airway': 1.0},
#   'Adenosine (Adenocard)': {'Adenosine (Adenocard)': 0.5, 'IV/IO': 0.5},
#   'Amiodarone (Cordarone)': {'Ondansetron (Zofran)': 1.0},
#   'Move Patient': {'ECG': 1.0},
#   'Dextrose 10 % Injectable Solution': {'ECG': 1.0},
#   'Heparin': {'Nitroglycerin': 0.2, 'Oxygen': 0.4, 'end': 0.2, 'ECG': 0.2},
#   'Glucagon (Glucagen)': {'end': 1.0},
#   'Epinephrine 1:1,000': {'Intubation': 0.3333333333333333,
#    'Epinephrine 1:1,000': 0.3333333333333333,
#    'Atropine': 0.3333333333333333},
#   'Enoxaparin': {'Oxygen': 1.0}},
#  'Cardiac Arrest': {'start': {'ECG': 0.08971553610503283,
#    'CPR': 0.3074398249452954,
#    'Oxygen': 0.21991247264770242,
#    'ETCO2 Capnography': 0.009846827133479213,
#    'BVM': 0.07986870897155361,
#    'Intubation': 0.12144420131291028,
#    'IV/IO': 0.03938730853391685,
#    'Epinephrine 1:10,000': 0.047045951859956234,
#    'Naloxone (Narcan)': 0.006564551422319475,
#    'Normal saline': 0.020787746170678335,
#    'Gastric Tube Insertion': 0.0010940919037199124,
#    'Defibrillation': 0.015317286652078774,
#    'Aspirin (ASA)': 0.0032822757111597373,
#    'Thoracostomy': 0.0010940919037199124,
#    'Clear Airway': 0.007658643326039387,
#    'Monitor/Care': 0.002188183807439825,
#    'Open/Position Airway': 0.006564551422319475,
#    'Amiodarone (Cordarone)': 0.00437636761487965,
#    'Epinephrine 1:1,000': 0.002188183807439825,
#    'Sodium Bicarbonate': 0.0010940919037199124,
#    'Albuterol (Proventil)': 0.0010940919037199124,
#    '10 ML calcium chloride 10 % Prefilled Syringe': 0.0010940919037199124,
#    'Stabilization/Splinting': 0.002188183807439825,
#    'Cardiac Pacing': 0.00437636761487965,
#    'Move Patient': 0.0010940919037199124,
#    'Bleeding Control': 0.0010940919037199124,
#    'CYANOKIT 5g': 0.0010940919037199124,
#    'Midazolam (Versed)': 0.0010940919037199124},
#   'ECG': {'CPR': 0.15468607825295724,
#    'Epinephrine 1:10,000': 0.11282984531392175,
#    'IV/IO': 0.19745222929936307,
#    'end': 0.12010919017288443,
#    'ECG': 0.16196542311191992,
#    'Clear Airway': 0.020018198362147407,
#    'BVM': 0.02456778889899909,
#    'Oxygen': 0.03548680618744313,
#    'Intubation': 0.060964513193812554,
#    'Midazolam (Versed)': 0.00545950864422202,
#    'ETCO2 Capnography': 0.017288444040036398,
#    'Cardiac Pacing': 0.0009099181073703367,
#    'Defibrillation': 0.034576888080072796,
#    '1745278': 0.0018198362147406734,
#    'Amiodarone (Cordarone)': 0.004549590536851683,
#    'Naloxone (Narcan)': 0.009099181073703366,
#    'Norepinephrine (Levophed)': 0.00272975432211101,
#    'Normal saline': 0.01637852593266606,
#    'Atropine': 0.0009099181073703367,
#    'Thoracostomy': 0.00272975432211101,
#    'Nitroglycerin': 0.0009099181073703367,
#    'Epinephrine 1:1,000': 0.0009099181073703367,
#    'Open/Position Airway': 0.00272975432211101,
#    'Albuterol (Proventil)': 0.0009099181073703367,
#    'Gastric Tube Insertion': 0.0018198362147406734,
#    'Sodium Bicarbonate': 0.00272975432211101,
#    'Dextrose 10 % Injectable Solution': 0.0009099181073703367,
#    'Stabilization/Splinting': 0.0009099181073703367,
#    'ROSC': 0.003639672429481347},
#   'CPR': {'Intubation': 0.10326499620349279,
#    'IV/IO': 0.1845102505694761,
#    'BVM': 0.14578587699316628,
#    'ECG': 0.13895216400911162,
#    'CPR': 0.0926347760060744,
#    'Defibrillation': 0.037965072133637055,
#    'Epinephrine 1:10,000': 0.10933940774487472,
#    'ETCO2 Capnography': 0.011389521640091117,
#    'end': 0.017463933181473046,
#    'Oxygen': 0.09415337889141989,
#    'Clear Airway': 0.02126044039483675,
#    'Gastric Tube Insertion': 0.0030372057706909645,
#    'Monitor/Care': 0.0030372057706909645,
#    'Stabilization/Splinting': 0.002277904328018223,
#    'Normal saline': 0.009870918754745633,
#    'Sodium Bicarbonate': 0.0015186028853454822,
#    'Naloxone (Narcan)': 0.00683371298405467,
#    'Open/Position Airway': 0.005315110098709187,
#    'Epinephrine 1:1,000': 0.0015186028853454822,
#    'Move Patient': 0.0015186028853454822,
#    'Dextrose 10 % Injectable Solution': 0.0007593014426727411,
#    'Amiodarone (Cordarone)': 0.0030372057706909645,
#    'Access Airway': 0.0007593014426727411,
#    'ROSC': 0.0030372057706909645,
#    'Thoracostomy': 0.0007593014426727411},
#   'Intubation': {'IV/IO': 0.1388888888888889,
#    'Epinephrine 1:10,000': 0.23774509803921567,
#    'Intubation': 0.056372549019607844,
#    'Naloxone (Narcan)': 0.012254901960784314,
#    'ETCO2 Capnography': 0.05228758169934641,
#    'BVM': 0.14133986928104575,
#    'CPR': 0.11683006535947713,
#    'Clear Airway': 0.03676470588235294,
#    'Gastric Tube Insertion': 0.013071895424836602,
#    'Oxygen': 0.03349673202614379,
#    'end': 0.014705882352941176,
#    'Sodium Bicarbonate': 0.00980392156862745,
#    'ECG': 0.06209150326797386,
#    'Midazolam (Versed)': 0.0032679738562091504,
#    'Defibrillation': 0.03431372549019608,
#    'Normal saline': 0.00980392156862745,
#    'Epinephrine 1:1,000': 0.0024509803921568627,
#    'Glucose Check': 0.0008169934640522876,
#    'Monitor/Care': 0.0008169934640522876,
#    'Vitals/Assess': 0.0008169934640522876,
#    'Nitroglycerin': 0.0008169934640522876,
#    'Amiodarone (Cordarone)': 0.004901960784313725,
#    'CPR Discontinued': 0.0008169934640522876,
#    'Dextrose 10 % Injectable Solution': 0.0032679738562091504,
#    'Move Patient': 0.0024509803921568627,
#    'Open/Position Airway': 0.0016339869281045752,
#    'Extrication': 0.0008169934640522876,
#    'ROSC': 0.004084967320261438,
#    'Stabilization/Splinting': 0.0016339869281045752,
#    'Norepinephrine (Levophed)': 0.0008169934640522876,
#    'Atropine': 0.0008169934640522876},
#   'IV/IO': {'CPR': 0.03546099290780142,
#    'IV/IO': 0.09131205673758866,
#    'Epinephrine 1:10,000': 0.4601063829787234,
#    'ECG': 0.07446808510638298,
#    'Normal saline': 0.061170212765957445,
#    'Intubation': 0.08421985815602837,
#    'BVM': 0.040780141843971635,
#    'Sodium Bicarbonate': 0.0026595744680851063,
#    'Glucose Check': 0.0008865248226950354,
#    'Clear Airway': 0.01152482269503546,
#    'Naloxone (Narcan)': 0.02127659574468085,
#    'Norepinephrine (Levophed)': 0.0026595744680851063,
#    'ETCO2 Capnography': 0.012411347517730497,
#    'Amiodarone (Cordarone)': 0.008865248226950355,
#    'Defibrillation': 0.031914893617021274,
#    'Oxygen': 0.015070921985815602,
#    'end': 0.020390070921985817,
#    'Thoracostomy': 0.0017730496453900709,
#    'Monitor/Care': 0.0026595744680851063,
#    'Epinephrine 1:1,000': 0.0062056737588652485,
#    '10 ML calcium chloride 10 % Prefilled Syringe': 0.0008865248226950354,
#    'Dexamethasone 10mg IV/IM': 0.0008865248226950354,
#    'Vagal Maneuver': 0.0008865248226950354,
#    'Dextrose 10 % Injectable Solution': 0.0008865248226950354,
#    'CPR Discontinued': 0.0008865248226950354,
#    'Calcium Chloride': 0.0008865248226950354,
#    'Atropine': 0.0017730496453900709,
#    'ROSC': 0.0026595744680851063,
#    'Gastric Tube Insertion': 0.0017730496453900709,
#    'CPAP/BiPAP': 0.0008865248226950354,
#    'Midazolam (Versed)': 0.0008865248226950354,
#    'Magnesium Sulfate': 0.0008865248226950354},
#   'Epinephrine 1:10,000': {'IV/IO': 0.02224694104560623,
#    'end': 0.16870596959584724,
#    'Epinephrine 1:10,000': 0.27437893956247683,
#    'Intubation': 0.11234705228031146,
#    'Sodium Bicarbonate': 0.047830923248053395,
#    'ECG': 0.04486466444197256,
#    'Normal saline': 0.027067111605487578,
#    'BVM': 0.004449388209121246,
#    'Clear Airway': 0.027067111605487578,
#    'CPR': 0.028550241008527995,
#    'Dextrose 10 % Injectable Solution': 0.009269558769002595,
#    'CPR Discontinued': 0.007415647015202077,
#    'Naloxone (Narcan)': 0.059695958472376714,
#    'ETCO2 Capnography': 0.028550241008527995,
#    '10 ML calcium chloride 10 % Prefilled Syringe': 0.004449388209121246,
#    'Defibrillation': 0.06192065257693734,
#    'Amiodarone (Cordarone)': 0.02224694104560623,
#    'Oxygen': 0.008898776418242492,
#    'Access Airway': 0.0003707823507601038,
#    'Thoracostomy': 0.0014831294030404152,
#    'Gastric Tube Insertion': 0.005932517612161661,
#    'Monitor/Care': 0.0029662588060808304,
#    'Atropine': 0.0014831294030404152,
#    'Norepinephrine (Levophed)': 0.0007415647015202076,
#    'Stabilization/Splinting': 0.0018539117538005192,
#    'Epinephrine 1:1,000': 0.0007415647015202076,
#    '1745278': 0.0003707823507601038,
#    'Open/Position Airway': 0.0007415647015202076,
#    'Glucose Check': 0.0003707823507601038,
#    'Move Patient': 0.0003707823507601038,
#    'Magnesium Sulfate': 0.0003707823507601038,
#    'Diphenhydramine (Benadryl)': 0.0003707823507601038,
#    'Calcium Gluconate 100 MG/ML Injectable Solution': 0.0007415647015202076,
#    'Midazolam (Versed)': 0.0003707823507601038,
#    'ROSC': 0.017797552836484983,
#    '0': 0.0003707823507601038,
#    'Albuterol (Proventil)': 0.0003707823507601038,
#    'Calcium Chloride': 0.0018539117538005192,
#    'Cricothyrotomy': 0.0003707823507601038},
#   'end': {},
#   'BVM': {'Naloxone (Narcan)': 0.009296148738379814,
#    'CPR': 0.2549800796812749,
#    'Intubation': 0.12217795484727756,
#    'Oxygen': 0.049136786188579015,
#    'ECG': 0.1806108897742364,
#    'Defibrillation': 0.04648074369189907,
#    'ETCO2 Capnography': 0.0398406374501992,
#    'Epinephrine 1:10,000': 0.10756972111553785,
#    'IV/IO': 0.10225763612217796,
#    'Move Patient': 0.0026560424966799467,
# ...
#    'ECG': 0.24812030075187969,
#    'Glucagon (Glucagen)': 0.03759398496240601,
#    'Normal saline': 0.015037593984962405,
#    'Dextrose 10 % Injectable Solution': 0.06015037593984962,
#    'Nebulizer Therapy': 0.007518796992481203,
#    'Cardiac Pacing': 0.007518796992481203,
#    'Dextrose': 0.015037593984962405,
#    'Albuterol (Proventil)': 0.015037593984962405,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.007518796992481203,
#    'Restraint Applied': 0.007518796992481203,
#    'Midazolam (Versed)': 0.007518796992481203},
#   'Dextrose 10 % Injectable Solution': {'ECG': 0.2717241379310345,
#    'ETCO2 Capnography': 0.005517241379310344,
#    'IV/IO': 0.15172413793103448,
#    'end': 0.45655172413793105,
#    'Normal saline': 0.01793103448275862,
#    'Glucagon (Glucagen)': 0.006896551724137931,
#    'Dextrose 10 % Injectable Solution': 0.02482758620689655,
#    'Dextrose': 0.015172413793103448,
#    'Glucose Check': 0.005517241379310344,
#    'Clear Airway': 0.002758620689655172,
#    'Midazolam (Versed)': 0.001379310344827586,
#    'Intubation': 0.004137931034482759,
#    'Oxygen': 0.020689655172413793,
#    'Monitor/Care': 0.001379310344827586,
#    'Naloxone (Narcan)': 0.006896551724137931,
#    'Patient Cooling/Warming': 0.001379310344827586,
#    'Epinephrine 1:10,000': 0.001379310344827586,
#    'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': 0.001379310344827586,
#    'Bleeding Control': 0.001379310344827586,
#    'Norepinephrine (Levophed)': 0.001379310344827586},
#   'ETCO2 Capnography': {'ECG': 0.2647058823529412,
#    'IV/IO': 0.29411764705882354,
#    'Oxygen': 0.058823529411764705,
#    'Naloxone (Narcan)': 0.058823529411764705,
#    'BVM': 0.029411764705882353,
#    'Glucose Check': 0.029411764705882353,
#    'end': 0.11764705882352941,
#    'Intubation': 0.058823529411764705,
#    'Glucagon (Glucagen)': 0.029411764705882353,
#    'ETCO2 Capnography': 0.058823529411764705},
#   'Adenosine (Adenocard)': {'ECG': 1.0},
#   'Normal saline': {'IV/IO': 0.13953488372093023,
#    'Dextrose 10 % Injectable Solution': 0.06976744186046512,
#    'Oxygen': 0.046511627906976744,
#    'ECG': 0.13953488372093023,
#    'end': 0.46511627906976744,
#    'Dextrose': 0.046511627906976744,
#    'Ondansetron (Zofran)': 0.046511627906976744,
#    'Glucose Check': 0.023255813953488372,
#    'Epinephrine 1:10,000': 0.023255813953488372},
#   'Glucose Check': {'Glucose Check': 0.26666666666666666,
#    'end': 0.3333333333333333,
#    'Dextrose': 0.03333333333333333,
#    'IV/IO': 0.2,
#    'Dextrose 10 % Injectable Solution': 0.03333333333333333,
#    'ECG': 0.1,
#    'Normal saline': 0.03333333333333333},
#   'BVM': {'ECG': 0.3333333333333333,
#    'Oxygen': 0.14285714285714285,
#    'IV/IO': 0.23809523809523808,
#    'CPR': 0.047619047619047616,
#    'Dextrose 10 % Injectable Solution': 0.047619047619047616,
#    'Intubation': 0.047619047619047616,
#    'Defibrillation': 0.047619047619047616,
#    'Naloxone (Narcan)': 0.047619047619047616,
#    'ETCO2 Capnography': 0.047619047619047616},
#   'Bleeding Control': {'ECG': 0.42857142857142855,
#    'end': 0.2857142857142857,
#    'Stabilization/Splinting': 0.14285714285714285,
#    'Dextrose 10 % Injectable Solution': 0.14285714285714285},
#   'Intubation': {'IV/IO': 0.24242424242424243,
#    'Oxygen': 0.15151515151515152,
#    'Clear Airway': 0.06060606060606061,
#    'ETCO2 Capnography': 0.09090909090909091,
#    'BVM': 0.09090909090909091,
#    'ECG': 0.15151515151515152,
#    'CPR': 0.030303030303030304,
#    'Ondansetron (Zofran)': 0.030303030303030304,
#    'Normal saline': 0.030303030303030304,
#    'Dextrose 10 % Injectable Solution': 0.030303030303030304,
#    'end': 0.09090909090909091},
#   'Aspirin (ASA)': {'ECG': 0.3333333333333333,
#    'Dextrose': 0.3333333333333333,
#    'end': 0.16666666666666666,
#    'Nitroglycerin': 0.16666666666666666},
#   'Naloxone (Narcan)': {'end': 0.3,
#    'Dextrose 10 % Injectable Solution': 0.13333333333333333,
#    'ECG': 0.1,
#    'Epinephrine 1:10,000': 0.06666666666666667,
#    'IV/IO': 0.1,
#    'BVM': 0.03333333333333333,
#    'Normal saline': 0.06666666666666667,
#    'Clear Airway': 0.03333333333333333,
#    'Naloxone (Narcan)': 0.03333333333333333,
#    'Oxygen': 0.06666666666666667,
#    'ETCO2 Capnography': 0.03333333333333333,
#    'Dextrose 50 % Injectable Solution': 0.03333333333333333},
#   'Clear Airway': {'Oxygen': 0.07692307692307693,
#    'Clear Airway': 0.038461538461538464,
#    'end': 0.15384615384615385,
#    'Intubation': 0.07692307692307693,
#    'ECG': 0.23076923076923078,
#    'Epinephrine 1:10,000': 0.038461538461538464,
#    'IV/IO': 0.23076923076923078,
#    'Glucagon (Glucagen)': 0.038461538461538464,
#    'Midazolam (Versed)': 0.038461538461538464,
#    'Dextrose 10 % Injectable Solution': 0.07692307692307693},
#   'Dexamethasone 10mg IV/IM': {'Oxygen': 0.3333333333333333,
#    'IV/IO': 0.3333333333333333,
#    'ECG': 0.3333333333333333},
#   'Ondansetron (Zofran)': {'end': 0.7272727272727273,
#    'Fentanyl': 0.09090909090909091,
#    'Normal saline': 0.09090909090909091,
#    'ECG': 0.09090909090909091},
#   'Midazolam (Versed)': {'Naloxone (Narcan)': 0.1,
#    'ECG': 0.2,
#    'Oxygen': 0.1,
#    'Normal saline': 0.1,
#    'Midazolam (Versed)': 0.1,
#    'Glucagon (Glucagen)': 0.1,
#    'end': 0.2,
#    'ETCO2 Capnography': 0.1},
#   'Monitor/Care': {'end': 0.2222222222222222,
#    'ECG': 0.6666666666666666,
#    'IV/IO': 0.1111111111111111},
#   'Wound Care': {'IV/IO': 1.0},
#   'Fentanyl': {'end': 0.5, 'ECG': 0.5},
#   'CPR': {'BVM': 0.5, 'IV/IO': 0.5},
#   'Epinephrine 1:10,000': {'Intubation': 0.3333333333333333,
#    'Epinephrine 1:10,000': 0.16666666666666666,
#    'Clear Airway': 0.3333333333333333,
#    'end': 0.16666666666666666},
#   'Restraint Applied': {'end': 0.125,
#    'ECG': 0.375,
#    'Glucagon (Glucagen)': 0.125,
#    'IV/IO': 0.25,
#    'Dextrose': 0.125},
#   'Albuterol 5mg / Ipratropium 0.5mg (DuoNeb)': {'Oxygen': 0.3333333333333333,
#    'end': 0.3333333333333333,
#    'Dextrose': 0.3333333333333333},
#   'Nebulizer Therapy': {'Normal saline': 1.0},
#   'Cardiac Pacing': {'Atropine': 1.0},
#   'Atropine': {'Atropine': 0.3333333333333333,
#    'Dextrose 10 % Injectable Solution': 0.3333333333333333,
#    'Normal saline': 0.3333333333333333},
#   'Patient Cooling/Warming': {'end': 0.14285714285714285,
#    'IV/IO': 0.2857142857142857,
#    'ECG': 0.42857142857142855,
#    'Clear Airway': 0.14285714285714285},
#   'Defibrillation': {'IV/IO': 1.0},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 1.0},
#   'Ipratropium (Atrovent)': {'Dextrose 10 % Injectable Solution': 0.2,
#    'end': 0.2,
#    'Dexamethasone (Decadron)': 0.4,
#    'Oxygen': 0.2},
#   'Glutose': {'end': 0.5454545454545454,
#    'Glutose': 0.13636363636363635,
#    'IV/IO': 0.1590909090909091,
#    'ECG': 0.13636363636363635,
#    'Glucagon (Glucagen)': 0.022727272727272728},
#   'Dextrose 25%': {'end': 0.5, 'ECG': 0.25, 'Ondansetron (Zofran)': 0.25},
#   'Dextrose 50 % Injectable Solution': {'end': 1.0},
#   'Vitals/Assess': {'IV/IO': 1.0},
#   'Dexamethasone (Decadron)': {'end': 1.0},
#   'Norepinephrine (Levophed)': {'Albuterol (Proventil)': 0.5, 'end': 0.5},
#   'Nitroglycerin': {'ECG': 1.0},
#   'Dextrose 5% in 0.45% NS': {'ECG': 1.0},
#   'Open/Position Airway': {'IV/IO': 1.0},
#   'Move Patient': {'ECG': 1.0}},
#  'Stroke': {'start': {'ECG': 0.5723830734966593,
#    'Oxygen': 0.05011135857461024,
#    'IV/IO': 0.29398663697104677,
#    'Normal saline': 0.012249443207126948,
#    'Monitor/Care': 0.011135857461024499,
#    'Intubation': 0.004454342984409799,
#    'Clear Airway': 0.004454342984409799,
#    'Nicardipine (Cardene)': 0.0033407572383073497,
#    'Midazolam (Versed)': 0.004454342984409799,
#    'CPR': 0.0022271714922048997,
#    'ETCO2 Capnography': 0.012249443207126948,
#    'Restraint Applied': 0.0011135857461024498,
#    'Glucose Check': 0.004454342984409799,
#    'Propofol Injection (Diprivan)': 0.0011135857461024498,
#    'BVM': 0.0011135857461024498,
#    'Naloxone (Narcan)': 0.0011135857461024498,
#    'Generic Medication Placeholder': 0.0022271714922048997,
#    'Dextrose': 0.0033407572383073497,
#    'Stabilization/Splinting': 0.0033407572383073497,
#    'Norepinephrine (Levophed)': 0.0011135857461024498,
#    'Ondansetron (Zofran)': 0.0022271714922048997,
#    'Diphenhydramine (Benadryl)': 0.0011135857461024498,
#    'Dextrose 10 % Injectable Solution': 0.0022271714922048997,
#    'Access Airway': 0.0011135857461024498,
#    'Aspirin (ASA)': 0.0011135857461024498,
#    'Cardiac Pacing': 0.0011135857461024498,
#    'Alteplase (Activase)': 0.0011135857461024498},
#   'ECG': {'IV/IO': 0.2798898071625344,
#    'Oxygen': 0.018732782369146005,
#    'ECG': 0.37300275482093664,
#    'end': 0.27823691460055094,
#    'Naloxone (Narcan)': 0.004407713498622589,
#    'Ondansetron (Zofran)': 0.0027548209366391185,
#    'Normal saline': 0.013223140495867768,
#    'Monitor/Care': 0.0011019283746556473,
#    'Intubation': 0.004407713498622589,
#    'ETCO2 Capnography': 0.0049586776859504135,
#    'Terbutaline Sulfate 1 MG/ML': 0.0005509641873278236,
#    'Midazolam (Versed)': 0.0027548209366391185,
#    'Aspirin (ASA)': 0.003305785123966942,
#    'Atropine': 0.0011019283746556473,
#    'Clear Airway': 0.003305785123966942,
#    'Defibrillation': 0.0011019283746556473,
#    'BVM': 0.0005509641873278236,
#    'Precedex': 0.0005509641873278236,
#    'Dextrose': 0.0011019283746556473,
#    'Generic Medication Placeholder': 0.0005509641873278236,
#    'Nicardipine (Cardene)': 0.0005509641873278236,
#    'Dextrose 10 % Injectable Solution': 0.0022038567493112946,
#    'CPAP/BiPAP': 0.0005509641873278236,
#    'Glucagon (Glucagen)': 0.0005509641873278236,
#    'Alteplase (Activase)': 0.0005509641873278236},
#   'IV/IO': {'ECG': 0.4788583509513742,
#    'end': 0.2938689217758985,
#    'Normal saline': 0.0306553911205074,
#    'Ondansetron (Zofran)': 0.006342494714587738,
#    'IV/IO': 0.09302325581395349,
#    'Monitor/Care': 0.005285412262156448,
#    'Naloxone (Narcan)': 0.017970401691331923,
#    'Clear Airway': 0.006342494714587738,
#    'Midazolam (Versed)': 0.015856236786469344,
#    'CPR': 0.0010570824524312897,
#    'Dextrose 10 % Injectable Solution': 0.015856236786469344,
#    'Oxygen': 0.015856236786469344,
#    'ETCO2 Capnography': 0.004228329809725159,
#    'Dextrose': 0.004228329809725159,
#    'CPAP/BiPAP': 0.0010570824524312897,
#    'Dexamethasone 10mg IV/IM': 0.0010570824524312897,
#    'Vitals/Assess': 0.0010570824524312897,
#    'Bleeding Control': 0.0010570824524312897,
#    'BVM': 0.0010570824524312897,
#    'Diphenhydramine (Benadryl)': 0.0010570824524312897,
#    'Aspirin (ASA)': 0.0010570824524312897,
#    'Intubation': 0.0010570824524312897,
#    'Glucagon (Glucagen)': 0.0021141649048625794},
#   'end': {},
#   'Oxygen': {'Intubation': 0.041666666666666664,
#    'ECG': 0.35833333333333334,
#    'end': 0.15833333333333333,
#    'IV/IO': 0.25,
#    'BVM': 0.075,
#    'ETCO2 Capnography': 0.025,
#    'CPAP/BiPAP': 0.016666666666666666,
#    'Albuterol (Proventil)': 0.008333333333333333,
#    'Normal saline': 0.008333333333333333,
#    'Clear Airway': 0.016666666666666666,
#    'Oxygen': 0.016666666666666666,
#    'Midazolam (Versed)': 0.008333333333333333,
#    'Aspirin (ASA)': 0.008333333333333333,
#    'Restraint Applied': 0.008333333333333333},
#   'Intubation': {'IV/IO': 0.18518518518518517,
#    'BVM': 0.25925925925925924,
#    'Intubation': 0.07407407407407407,
#    'ECG': 0.2222222222222222,
#    'Naloxone (Narcan)': 0.037037037037037035,
#    'Oxygen': 0.07407407407407407,
#    'CPR': 0.037037037037037035,
#    'Open/Position Airway': 0.037037037037037035,
#    'Midazolam (Versed)': 0.037037037037037035,
#    'end': 0.037037037037037035},
#   'Naloxone (Narcan)': {'end': 0.3333333333333333,
#    'ECG': 0.2777777777777778,
#    'Naloxone (Narcan)': 0.05555555555555555,
#    'IV/IO': 0.16666666666666666,
#    'Oxygen': 0.027777777777777776,
#    'ETCO2 Capnography': 0.05555555555555555,
#    'Clear Airway': 0.08333333333333333},
#   'Ondansetron (Zofran)': {'IV/IO': 0.07142857142857142,
#    'end': 0.6428571428571429,
#    'ECG': 0.14285714285714285,
#    'Monitor/Care': 0.07142857142857142,
#    'Normal saline': 0.07142857142857142},
#   'Normal saline': {'ECG': 0.3188405797101449,
#    'IV/IO': 0.2463768115942029,
#    'end': 0.2898550724637681,
#    'Dextrose 10 % Injectable Solution': 0.043478260869565216,
#    'Norepinephrine (Levophed)': 0.014492753623188406,
#    'Dextrose': 0.014492753623188406,
#    'Epinephrine 1:10,000': 0.014492753623188406,
#    'Oxygen': 0.028985507246376812,
#    'Ondansetron (Zofran)': 0.014492753623188406,
#    'Naloxone (Narcan)': 0.014492753623188406},
#   'Monitor/Care': {'ECG': 0.75,
#    'end': 0.05,
#    'IV/IO': 0.1,
#    'Monitor/Care': 0.05,
#    'CPAP/BiPAP': 0.05},
#   'BVM': {'Oxygen': 0.1,
#    'Intubation': 0.1,
#    'ECG': 0.2,
#    'ETCO2 Capnography': 0.05,
#    'end': 0.15,
#    'IV/IO': 0.2,
#    'Midazolam (Versed)': 0.1,
#    'CPR': 0.05,
#    'Naloxone (Narcan)': 0.05},
#   'Clear Airway': {'ECG': 0.34782608695652173,
#    'Oxygen': 0.13043478260869565,
#    'BVM': 0.043478260869565216,
#    'IV/IO': 0.043478260869565216,
#    'Midazolam (Versed)': 0.043478260869565216,
#    'end': 0.13043478260869565,
#    'CPAP/BiPAP': 0.043478260869565216,
#    'Clear Airway': 0.08695652173913043,
#    'Intubation': 0.043478260869565216,
#    'Naloxone (Narcan)': 0.08695652173913043},
#   'Dextrose 10 % Injectable Solution': {'end': 0.5769230769230769,
#    'Epinephrine 1:10,000': 0.038461538461538464,
#    'ECG': 0.2692307692307692,
#    'Dextrose': 0.038461538461538464,
#    'Glucagon (Glucagen)': 0.038461538461538464,
#    'Dextrose 10 % Injectable Solution': 0.038461538461538464},
#   'Midazolam (Versed)': {'end': 0.25,
#    'ECG': 0.25,
#    'ETCO2 Capnography': 0.09375,
#    'Oxygen': 0.1875,
#    'IV/IO': 0.09375,
#    'Propofol (Diprivan)': 0.03125,
#    'Intubation': 0.03125,
#    'Midazolam (Versed)': 0.0625},
#   'ETCO2 Capnography': {'Naloxone (Narcan)': 0.05,
#    'CPAP/BiPAP': 0.05,
#    'ECG': 0.375,
#    'Glucose Check': 0.025,
#    'Oxygen': 0.1,
#    'end': 0.125,
#    'Intubation': 0.05,
#    'IV/IO': 0.1,
#    'ETCO2 Capnography': 0.1,
#    'Atropine': 0.025},
#   'Nicardipine (Cardene)': {'Propofol Injection (Diprivan)': 0.2,
#    'CPAP/BiPAP': 0.2,
#    'ETCO2 Capnography': 0.2,
#    'ECG': 0.4},
#   'Propofol Injection (Diprivan)': {'Fentanyl': 0.5,
#    'CPAP/BiPAP': 0.25,
#    'IV/IO': 0.25},
#   'Fentanyl': {'Normal saline': 0.5, 'end': 0.5},
#   'CPAP/BiPAP': {'Propofol Injection (Diprivan)': 0.1,
#    'Midazolam (Versed)': 0.1,
#    'ECG': 0.5,
#    'IV/IO': 0.1,
#    'end': 0.2},
#   'Terbutaline Sulfate 1 MG/ML': {'end': 1.0},
#   'CPR': {'Stabilization/Splinting': 0.2,
#    'Epinephrine 1:10,000': 0.2,
#    'Oxygen': 0.2,
#    'Intubation': 0.2,
#    'ECG': 0.2},
#   'Stabilization/Splinting': {'IV/IO': 0.2, 'ECG': 0.8},
#   'Epinephrine 1:10,000': {'Dextrose 10 % Injectable Solution': 0.25,
#    'end': 0.25,
#    'Epinephrine 1:10,000': 0.25,
#    'Defibrillation': 0.25},
#   'Aspirin (ASA)': {'ECG': 0.4444444444444444,
#    'IV/IO': 0.1111111111111111,
#    'end': 0.4444444444444444},
#   'Restraint Applied': {'ECG': 0.5, 'end': 0.5},
#   'Glucose Check': {'ECG': 0.4, 'IV/IO': 0.4, 'Stabilization/Splinting': 0.2},
#   'Norepinephrine (Levophed)': {'end': 0.5,
#    'Propofol Injection (Diprivan)': 0.5},
#   'Atropine': {'ECG': 0.3333333333333333,
#    'IV/IO': 0.3333333333333333,
#    'ETCO2 Capnography': 0.3333333333333333},
#   'Generic Medication Placeholder': {'IV/IO': 0.3333333333333333,
#    'ETCO2 Capnography': 0.3333333333333333,
#    'Oxygen': 0.3333333333333333},
#   'Dextrose': {'Normal saline': 0.07692307692307693,
#    'ECG': 0.3076923076923077,
#    'IV/IO': 0.3076923076923077,
#    'Dextrose': 0.15384615384615385,
#    'end': 0.15384615384615385},
#   'Defibrillation': {'Normal saline': 0.3333333333333333,
#    'ECG': 0.3333333333333333,
#    'end': 0.3333333333333333},
#   'Precedex': {'Oxygen': 1.0},
#   'Albuterol (Proventil)': {'Ipratropium (Atrovent)': 0.5, 'ECG': 0.5},
#   'Ipratropium (Atrovent)': {'ECG': 1.0},
#   'Dexamethasone 10mg IV/IM': {'Albuterol (Proventil)': 1.0},
#   'Diphenhydramine (Benadryl)': {'Oxygen': 0.5, 'ECG': 0.5},
#   'Glucagon (Glucagen)': {'ECG': 0.25, 'end': 0.5, 'IV/IO': 0.25},
#   'Vitals/Assess': {'end': 1.0},
#   'Bleeding Control': {'end': 1.0},
#   'Access Airway': {'Monitor/Care': 1.0},
#   'Propofol (Diprivan)': {'Nicardipine (Cardene)': 1.0},
#   'Open/Position Airway': {'Naloxone (Narcan)': 1.0},
#   'Cardiac Pacing': {'ECG': 1.0},
#   'Alteplase (Activase)': {'ECG': 0.5, 'end': 0.5}}}

# %%
# #get labels from dictionaries

# label_df = pd.DataFrame()

# for f in ['Complied list of Procedures.xlsx', 'Complied list of ODEMSA Medications.xlsx']:
#     data = pd.read_excel(f)
#     label_df = label_df.append(data)
    
# label_df.columns = ['ID', 0, 1,2,3]
# label_df['ID'] = label_df['ID'].astype(str)
# label_df = label_df.set_index('ID')


# label_df

# %%
# #turn dataframe into dictionary

# labels = label_df.T.to_dict('list')

# labels

# %%
# #convert to dataframe - use multiindexing
# dfs = {}

# for impression, graph in graphs.items():
#     nodes = []
#     node_labels = []

#     next_node_in_sequence = []
#     next_node_labels = []
#     frequencies = []

    
#     for node, dictionary in graph.items():
#         node_label = ""
#         if node_label in labels: node_label = labels[node][0]
#         for next_node, frequency in dictionary.items():
#             next_node_label = ""
#             if next_node in labels: next_node_label = labels[next_node][0]
            
#             nodes.append(node)
#             node_labels.append(node_label)
#             next_node_in_sequence.append(next_node)
#             next_node_labels.append(next_node_label)
#             frequencies.append(frequency)
            
#     graph_df = pd.DataFrame(nodes, columns = ['Nodes'])
#     graph_df['Node label'] = node_labels
#     graph_df['Edges'] = next_node_in_sequence
#     graph_df['Edges label'] = next_node_labels
#     graph_df['Frequency'] = frequencies
#     graph_df = graph_df.set_index(['Nodes', 'Node label', 'Edges'])
    
#     dfs[impression] = graph_df

# %%
# dfs

# %%
#write out to excel

# writer = pd.ExcelWriter( 'RQ4 Markov Chain Frequencies.xlsx', engine='xlsxwriter')

# for impression, df in dfs.items():    
#     df.to_excel(writer, sheet_name=impression)
    
# writer.save()

# %%
# #make visualization
# import networkx as nx
# from networkx.drawing import nx_pydot
# from graphviz import Source
# from pyvis.network import Network
# form pyvis.options import Layout

# vis = {}
# for impression, graph in graphs.items():
    
# #     used = set()    
# #     nt = Network(directed=True, notebook=True)
    
# #     i = 0    
# #     for node, edge_list in graph.items():
# #         if node not in used: 
# #             nt.add_node(node, label=node, level = i)
# #             used.add(node)
# #             i += 1
# #         for edge, freq in edge_list.items():
# #             nt.add_node(edge)
# #             nt.add_edge(node, edge, weight = freq)
    
# #     nt.show("example.html")
    
#     #initialize graph
#     DG = nx.MultiDiGraph()

#     #add all nodes
#     DG.add_nodes_from(graph.keys())

#     #make edge list - format
#     edges = []
#     for node, edge_list in graph.items():
#         for edge, freq in edge_list.items():
#             edges.append((node,edge, {'label': round(freq,2)}))

#     #add all edges
#     DG.add_edges_from(edges)
    
#     net = Network(directed=True, notebook=True)

#     net.from_nx(DG)

#     net.show("example.html")

    
#     #draw to visual representation
#     nx_pydot.write_dot(DG, impression + ' multig.dot')
    
    
#     src = Source.from_file(impression + ' multig.dot')
#     vis[impression] = src
    
#     #save and render
#     src.render(impression+ ' graph.gv', view=True)

# %%
#     #add all edges
#     set_separation(nt, 100)

#     nt.show("example.html")

# %%
#filter

#make visualization
import networkx as nx
from networkx.drawing import nx_pydot
from graphviz import Source

vis = {}
for impression, graph in graphs.items():

    #initialize graph
    DG = nx.MultiDiGraph()

    #add all nodes
    for node in graph.keys():
        if node == 'start' or node == 'end':
            DG.add_node(node, style = 'filled')
        else:
            DG.add_node(node)

    #make edge list - format
    edges = []
    for node, edge_list in graph.items():
        for edge, freq in edge_list.items():
            if freq >= 2:  # identify edges with freq < 0.02
                edges.append((node,edge, {'label': round(freq,2)}))
    DG.add_edges_from(edges)
    
    # "backtracking" from the edges, delete any predecessors and successors disconnected from the start/end 
    remove = [node for node in nx.nodes(DG) if node != 'start' and node != 'end' and ('start' not in nx.all_neighbors(DG, node) or 'end' not in nx.all_neighbors(DG, node)) ]
    DG.remove_nodes_from(remove)

    
    #draw to visual representation
#     nx_pydot.write_dot(DG, impression + ' multig.dot')
    
#     src = Source.from_file(impression + ' multig.dot')
#     vis[impression] = src
    
#     #save and render
#     src.render('All nodes' + impression, view=True)
