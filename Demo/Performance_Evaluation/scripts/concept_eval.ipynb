# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./concept_results.csv')
updated_gt = []
updated_out_wc = []
updated_out_woc = []

print(df)
for index, row in df.iterrows():
    recording = row["Recording"]
    gt = str(row["Ground Truth"])
 
    # concept_arr = []

    # for idx,concept in enumerate(out_woc.splitlines()):
    #     concept = concept.strip("()")
    #     concept = concept.lower()
    #     concept_arr.append(concept)
    
    # out_woc = concept_arr
    # updated_out_woc.append(out_woc)
    
    gt = gt.split(";")
    for idx,concept in enumerate(gt):
        concept = concept.strip("\r\n")
        concept = concept.lower()
        gt[idx] = concept
        # print(concept)
    updated_gt.append(gt)

df["Ground Truth"] = updated_gt

print(df)
# Out:
#          Recording                                       Ground Truth  \
# 0   000_190105.wav  age, True, 55;\ngender, True, male;\nloss of c...
# 1   001_190105.wav  age, True, 51;\ngender, True, female;\nshortne...
# 2   002_190105.wav  age, True, 35;\r\ngender, True, female;\r\nabd...
# 3   003_190105.wav  vomiting, True, vomiting;\r\ngcs, True, 10;\r\...
# 4   004_190105.wav  gender, True, male;\r\nseizures, True, seizure...
# 5   005_190105.wav  age, True, 89;\r\ngender, True, female;\r\nsho...
# 6   006_190105.wav  gender, True, female;\r\nchest pain, True, che...
# 7   007_190105.wav  chest pain, True, chest pain;\r\nage, True, 57...
# 8   008_190105.wav  age, True, 26;\r\ngender, True, male;\r\nconfu...
# 9   009_190105.wav  gender, True, female;\nabdominal pain, True, a...
# 10  010_190105.wav  age, True, 97;\r\ngender, True, female;\r\nmal...
# 11  011_190105.wav  shortness of breath, True, shortness of breath...
#
#                                  Extracted Output WOC  \
# ...

# %% [markdown]
# #### TP, FP, FN Extraction for Chunked Audio

# %%
chunked_df = pd.read_csv('./concept_results-chunked.csv')
chunked_df = chunked_df.fillna('')

true_positives = []
false_positives = []
false_negatives = []

for index, row in df.iterrows():
    recording = row["Recording"]
    gt = row["Ground Truth"]

    # out_wc = row["Extracted Output WC"]

    precision_for_all_chunks = []
    recall_for_all_chunks = []
    f1_for_all_chunks = []

    for idx, chunk_row in chunked_df.iterrows():
        print(recording + " Chunk: ",idx+1)
        chunked_out = chunk_row[recording]
        # print(chunked_out)

        concept_arr = []


        for idxx,concept in enumerate(chunked_out.splitlines()):
            concept = concept.strip("() ")
            concept = concept.lower()
            # print(concept)
            
            concept_arr.append(concept)
        

        chunked_out = concept_arr

        # chunked_df.at[idx,recording] = chunked_out

        print(chunked_out)

        intersection = (set(gt) & set(chunked_out))
        tp = intersection #extracted concepts that are true
        
        fp = set(chunked_out) - tp #extracted concepts that are false
        
        
        fn = set(gt) - set(chunked_out) #missed extracting true concepts
        
        fn  = [i for i in fn if i]

        
        true_positives = (list(tp))
        false_positives = (list(fp))
        false_negatives = (list(fn))
        
        print("true_positives: ",true_positives)
        print("false_positives: ",false_positives)
        print("false_negatives: ",false_negatives)

        try:
            precision = len(true_positives)/(len(true_positives)+len(false_positives))
        except ZeroDivisionError:
            precision = 0

        try:
            recall = len(true_positives)/(len(true_positives)+len(false_negatives))
        except ZeroDivisionError:
            recall = 0

        try:
            f1 = 2*(precision*recall)/(precision+recall)
        except ZeroDivisionError:
            f1 = 0

        precision_for_all_chunks.append(precision)
        recall_for_all_chunks.append(recall)
        f1_for_all_chunks.append(f1)
        
        print("Precision: ",precision)
        print("Recall: ",recall)
        print("F1: ",f1)

        print("")
# Out:
# 000_190105.wav Chunk:  1
# ['gender, true, male', 'age, true, 55', 'loss of consciousness, true, unconscious']
# true_positives:  ['loss of consciousness, true, unconscious', 'age, true, 55', 'gender, true, male']
# false_positives:  []
# false_negatives:  ['resp, true, 5', 'bradypnea, true, 5', 'pulse, true, 118', 'bp, true, 205/119', 'hypertension, true, 205/119', 'pale, true, pale', 'spo2, true, 94', 'glucose, true, 126', 'tachycardia, true, 118']
# Precision:  1.0
# Recall:  0.25
# F1:  0.4
#
# 000_190105.wav Chunk:  2
# ['gender, true, male', 'age, true, 55', 'loss of consciousness, true, unconscious']
# true_positives:  ['loss of consciousness, true, unconscious', 'age, true, 55', 'gender, true, male']
# false_positives:  []
# false_negatives:  ['resp, true, 5', 'bradypnea, true, 5', 'pulse, true, 118', 'bp, true, 205/119', 'hypertension, true, 205/119', 'pale, true, pale', 'spo2, true, 94', 'glucose, true, 126', 'tachycardia, true, 118']
# Precision:  1.0
# Recall:  0.25
# ...
